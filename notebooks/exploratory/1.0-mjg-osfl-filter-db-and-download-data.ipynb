# %% [markdown]
# # Data Downloader and cleaner
# This notebook develops a method to clean the database and download data

# %% [markdown]
# `meta` refers to the metadata of the audio clips, and is read from TrainingData_BU&Public_CWS.csv
#
# Operations performed:
# - Remove samples with abundance labels 'too many to tag'
# - Include only vocalizations with type 'song'
# - Vocalizations tagged outside of wildtrax aren't included since the start and end times can be inaccurate.
# - The 'tag_rating' field has been left unfiltered.
# - Only olive-sided flycatcher vocalizations are included.
# - Convert Id fields from float type to int type using pd.astype()
# - Some clips in the .csv file don't have a url to the audio data. These are skipped.
# - the olive sided flycatcher database is exported to processed/osfls
# <br>
#
# Todo:
# - Check to make sure that tags with a different tag id but the same recording id do actually refer to the same recording - and not just duplicated recording ids for different recordings.

# %%
import pandas as pd
import requests
import re
from pathlib import Path

# %%
data_path = Path('../../data/')

# %%
meta = pd.read_csv(data_path/'raw/TrainingData_BU&Public_CWS.csv')

meta['clip_id'] = meta.index

# Reorder columns so that the clip_id is at the start
cols = list(meta.columns)
meta = meta[cols[-1:] + cols[:-1]]
# Out:
# /var/folders/hy/36n7jr6x3h74ddx507dc12_00000gn/T/ipykernel_22072/3559803524.py:1: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   meta = pd.read_csv(data_path/'raw/TrainingData_BU&Public_CWS.csv')

# %%
len(meta)
# Out:
# 1152840

# %%
def display_all(df, rows=10, cols=200):
    with pd.option_context("display.max_columns", cols):
           display(df)

# %% [markdown]
# # Clean the data

# %% [markdown]
# One of the entries in the .csv file didn't contain Id tags. Remove this from the dataset

# %%
meta.drop(index=1152839, inplace=True)

# %%
# convert ids to integer types
meta.recording_id = meta.recording_id.astype(int)
meta.location_id = meta.location_id.astype(int)
meta.task_id = meta.task_id.astype(int)
meta.tag_id = meta.tag_id.astype(int)

# %% [markdown]
# Some of the abundance types are stored as strings and some are numeric. Convert all to same type.

# %%
meta.abundance = meta.abundance.astype(str)

# %%
display_all(meta.head())
# Out:
#    clip_id organization             project  project_id     location  \
# 0        0           BU  Alberta Archetypes        1501  BBS-4139-20
# 1        1           BU  Alberta Archetypes        1501  BBS-4139-27
# 2        2           BU  Alberta Archetypes        1501  BBS-4139-28
# 3        3           BU  Alberta Archetypes        1501  BBS-4139-28
# 4        4           BU  Alberta Archetypes        1501  BBS-4139-36
#
#    location_id  recording_date_time  recording_id task_method  task_id  \
# 0        87850  2021-07-03 06:56:02        331758        None   595843
# 1        87844  2021-07-03 07:42:01        331765        None   595844
# 2        87842  2021-07-03 07:47:01        331764        None   595845
# 3        87842  2021-07-03 07:47:01        331764        None   595845
# 4        87834  2022-06-26 08:24:04        358620        None   595846
#
#   aru_task_status species_code species_common_name    species_scientific_name  \
# 0     Transcribed         SAVS    Savannah Sparrow  PASSERCULUS SANDWICHENSIS
# 1     Transcribed         SAVS    Savannah Sparrow  PASSERCULUS SANDWICHENSIS
# 2     Transcribed         SAVS    Savannah Sparrow  PASSERCULUS SANDWICHENSIS
# 3     Transcribed         SAVS    Savannah Sparrow  PASSERCULUS SANDWICHENSIS
# 4     Transcribed         OVEN            Ovenbird        SEIURUS AUROCAPILLA
#
#   species_class  detection_time  task_duration  tag_duration min_tag_freq  \
# 0          Aves           10.74          180.0          2.51      2.01kHz
# 1          Aves           20.35          180.0          2.51      2.29kHz
# 2          Aves            7.18          180.0          2.51      2.19kHz
# 3          Aves           71.73          180.0          2.51      1.63kHz
# 4          Aves            2.75          180.0          2.57      2.16kHz
#
#   max_tag_freq   tag_id  individual_order vocalization abundance  tag_rating  \
# 0     10.09kHz  3212033               1.0         Song         1         NaN
# 1     10.32kHz  3212034               1.0         Song         1         NaN
# 2     10.79kHz  3212035               1.0         Song         1         NaN
# 3     10.65kHz  3212036               1.0         Song         1         NaN
# 4     10.92kHz  3212037               1.0         Song         1         NaN
#
#   tag_is_verified  clip_channel_used      observer  observer_user_id  \
# 0               f                1.0  Not Assigned              -1.0
# 1               f                1.0  Not Assigned              -1.0
# 2               f                1.0  Not Assigned              -1.0
# 3               f                1.0  Not Assigned              -1.0
# 4               f                1.0  Not Assigned              -1.0
#
#    verifier_user_id  left_full_freq_tag_rms_peak_dbfs  \
# 0               NaN                            -41.64
# 1               NaN                            -22.50
# 2               NaN                            -23.62
# 3               NaN                            -15.98
# 4               NaN                            -36.45
#
#    left_full_freq_tag_rms_trough_dbfs  left_full_freq_tag_pk_count  \
# 0                              -55.62                          2.0
# 1                              -39.54                          2.0
# 2                              -52.42                          2.0
# 3                              -28.24                          2.0
# 4                              -50.15                          2.0
#
#    left_full_freq_tag_dc_offset  left_full_freq_tag_min_level  \
# 0                     -0.000014                     -0.020752
# 1                     -0.000087                     -0.137454
# 2                      0.000045                     -0.149939
# 3                     -0.000270                     -0.317960
# 4                     -0.000026                     -0.041443
#
#    left_full_freq_tag_max_level  left_full_freq_tag_peak_level_dbfs  \
# 0                      0.017666                              -33.66
# 1                      0.144287                              -16.82
# 2                      0.135607                              -16.48
# 3                      0.371485                               -8.60
# 4                      0.051636                              -25.74
#
#    left_freq_filter_tag_rms_peak_dbfs  left_freq_filter_tag_rms_trough_dbfs  \
# 0                              -42.32                                -67.30
# 1                              -41.80                                -64.05
# 2                              -51.09                                -66.13
# 3                              -46.94                                -65.00
# 4                              -40.94                                -57.32
#
#    left_freq_filter_tag_pk_count  left_freq_filter_tag_dc_offset  \
# 0                            2.0                             0.0
# 1                            2.0                             0.0
# 2                            2.0                             0.0
# 3                            2.0                             0.0
# 4                            2.0                             0.0
#
#    left_freq_filter_tag_min_level  left_freq_filter_tag_max_level  \
# 0                       -0.016110                        0.016191
# 1                       -0.036974                        0.035904
# 2                       -0.007927                        0.008014
# 3                       -0.013312                        0.013227
# 4                       -0.033356                        0.035675
#
#    left_freq_filter_tag_peak_level_dbfs  right_full_freq_tag_rms_peak_dbfs  \
# 0                                -35.81                                NaN
# 1                                -28.64                                NaN
# 2                                -41.92                                NaN
# 3                                -37.52                                NaN
# 4                                -28.95                                NaN
#
#    right_full_freq_tag_rms_trough_dbfs  right_full_freq_tag_pk_count  \
# 0                                  NaN                           NaN
# 1                                  NaN                           NaN
# 2                                  NaN                           NaN
# 3                                  NaN                           NaN
# 4                                  NaN                           NaN
#
#    right_full_freq_tag_dc_offset  right_full_freq_tag_min_level  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    right_full_freq_tag_max_level  right_full_freq_tag_peak_level_dbfs  \
# 0                            NaN                                  NaN
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                            NaN                                  NaN
#
#    right_freq_filter_tag_rms_peak_dbfs  right_freq_filter_tag_rms_trough_dbfs  \
# 0                                  NaN                                    NaN
# 1                                  NaN                                    NaN
# 2                                  NaN                                    NaN
# 3                                  NaN                                    NaN
# 4                                  NaN                                    NaN
#
#    right_freq_filter_tag_pk_count  right_freq_filter_tag_dc_offset  \
# 0                             NaN                              NaN
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
#
#    right_freq_filter_tag_min_level  right_freq_filter_tag_max_level  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    right_freq_filter_tag_peak_level_dbfs tagged_in_wildtrax  \
# 0                                    NaN                  f
# 1                                    NaN                  f
# 2                                    NaN                  f
# 3                                    NaN                  f
# 4                                    NaN                  f
#
#                                                  url  \
# 0  https://portal.wildtrax.ca/home/aru-tasks/reco...
# 1  https://portal.wildtrax.ca/home/aru-tasks/reco...
# 2  https://portal.wildtrax.ca/home/aru-tasks/reco...
# 3  https://portal.wildtrax.ca/home/aru-tasks/reco...
# 4  https://portal.wildtrax.ca/home/aru-tasks/reco...
#
#                                  tag_spectrogram_url  \
# 0  https://wildtrax-aru.s3.us-west-2.amazonaws.co...
# 1  https://wildtrax-aru.s3.us-west-2.amazonaws.co...
# 2  https://wildtrax-aru.s3.us-west-2.amazonaws.co...
# 3  https://wildtrax-aru.s3.us-west-2.amazonaws.co...
# 4  https://wildtrax-aru.s3.us-west-2.amazonaws.co...
#
#                                             clip_url sensorId  tasks  status
# 0  https://wildtrax-aru.s3.us-west-2.amazonaws.co...      ARU    357  Active
# 1  https://wildtrax-aru.s3.us-west-2.amazonaws.co...      ARU    357  Active
# 2  https://wildtrax-aru.s3.us-west-2.amazonaws.co...      ARU    357  Active
# 3  https://wildtrax-aru.s3.us-west-2.amazonaws.co...      ARU    357  Active
# 4  https://wildtrax-aru.s3.us-west-2.amazonaws.co...      ARU    357  Active

# %% [markdown]
# Make an index called 'clip index' which will preserve the unique index of each clip after the dataframe is filtered, exported and imported elsewhere.

# %%
meta['clip_index'] = meta.index

# %%
meta.abundance.value_counts()
# Out:
# 1       1024057
# nan       49875
# TMTT      40077
# CI 1      17247
# CI 3      11324
# CI 2       8411
# 2          1167
# 3           342
# 5           126
# 4           125
# 6            36
# 7            28
# 8            14
# 10            9
# 9             1
# Name: abundance, dtype: int64

# %%
# Drop tmtt abundance tags.
tmtt_idxs = meta[meta.abundance=='TMTT'].index
meta.drop(tmtt_idxs, inplace=True)

# %%
# Drop non song vocalizations
not_song_idxs = meta[meta.vocalization!='Song'].index
meta.drop(not_song_idxs, inplace=True)

# %%
# Drop recordings not labeled in wildtrax
labeled_elsewhere_idxs = meta[meta.tagged_in_wildtrax=='f'].index
meta.drop(labeled_elsewhere_idxs, inplace=True)

# %%
# choose OSFL entries
osfl_idxs = meta[meta.species_code=='OSFL'].index
osfls = meta.loc[osfl_idxs]

# %% [markdown]
# Add a column named `file_type` to the dataframe. This is done only to samples with a clip_url.

# %%
osfls['file_type'] = None
for idx in osfls[~osfls.clip_url.isna()].index:
    
    osfls['file_type'][idx] = osfls['clip_url'][idx].split('.')[-1]
# Out:
# /var/folders/hy/36n7jr6x3h74ddx507dc12_00000gn/T/ipykernel_22072/3830306749.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   osfls['file_type'][idx] = osfls['clip_url'][idx].split('.')[-1]

# %% [markdown]
# See how the file_type has been added to the meta dataframe as well as the osfls dataframe to understand why the error message above was generated.

# %%
meta.head()
# Out:
#      clip_id organization                         project  project_id  \
# 382      382           BU              Alberta Archetypes        1501
# 425      425           BU  Amplitude Quality Testing 2020         293
# 427      427           BU  Amplitude Quality Testing 2020         293
# 428      428           BU  Amplitude Quality Testing 2020         293
# 429      429           BU  Amplitude Quality Testing 2020         293
#
#        location  location_id  recording_date_time  recording_id task_method  \
# 382   P-E0-1-10       308678  2022-06-05 06:51:00        416962        None
# 425  AM-403-SE2        36043  2017-06-15 04:46:00         92051        None
# 427  AM-403-SE2        36043  2017-06-15 04:46:00         92051        None
# 428  AM-403-SE2        36043  2017-06-15 04:46:00         92051        None
# 429  AM-403-SE2        36043  2017-06-15 04:46:00         92051        None
#
#      task_id  ... right_freq_filter_tag_max_level  \
# 382   596169  ...                             NaN
# 425    87956  ...                        0.063139
# 427    87898  ...                        0.036900
# 428    87840  ...                        0.062714
# 429    87927  ...                        0.040078
#
#     right_freq_filter_tag_peak_level_dbfs tagged_in_wildtrax  \
# 382                                   NaN                  t
# 425                                -23.17                  t
# 427                                -27.88                  t
# 428                                -23.78                  t
# 429                                -27.94                  t
#
#                                                    url  \
# 382  https://portal.wildtrax.ca/home/aru-tasks/reco...
# 425  https://portal.wildtrax.ca/home/aru-tasks/reco...
# 427  https://portal.wildtrax.ca/home/aru-tasks/reco...
# 428  https://portal.wildtrax.ca/home/aru-tasks/reco...
# 429  https://portal.wildtrax.ca/home/aru-tasks/reco...
#
#                                    tag_spectrogram_url  \
# 382  https://wildtrax-aru.s3.us-west-2.amazonaws.co...
# 425  https://wildtrax-aru.s3.us-west-2.amazonaws.co...
# 427  https://wildtrax-aru.s3.us-west-2.amazonaws.co...
# 428  https://wildtrax-aru.s3.us-west-2.amazonaws.co...
# 429  https://wildtrax-aru.s3.us-west-2.amazonaws.co...
#
#                                               clip_url  sensorId  tasks  \
# 382  https://wildtrax-aru.s3.us-west-2.amazonaws.co...       ARU    357
# 425  https://wildtrax-aru.s3.us-west-2.amazonaws.co...       ARU    174
# 427  https://wildtrax-aru.s3.us-west-2.amazonaws.co...       ARU    174
# 428  https://wildtrax-aru.s3.us-west-2.amazonaws.co...       ARU    174
# 429  https://wildtrax-aru.s3.us-west-2.amazonaws.co...       ARU    174
#
#                   status clip_index
# 382               Active        382
# 425  Published - Private        425
# 427  Published - Private        427
# 428  Published - Private        428
# 429  Published - Private        429
#
# [5 rows x 66 columns]

# %% [markdown]
# # drop entries with a missing clip_url field from OSFLs

# %%
len(osfls)
# Out:
# 5167

# %%
osfls.drop(osfls.loc[osfls.clip_url.isna()].index, inplace=True)

# %%
len(osfls)
# Out:
# 5163

# %% [markdown]
# # Download the audio samples

# %% [markdown]
# 1. Get the URL from the database (example)

# %%
url = osfls.clip_url.iloc[0]

# %%
url
# Out:
# 'https://wildtrax-aru.s3.us-west-2.amazonaws.com/df7f6bdc-9300-4738-9ddb-81d84d448400/687a4de556e1439fa624365426dcb3b0.mp3'

# %% [markdown]
# 2. Extract the file type from the url (example)

# %%
url.split('.')[-1]
# Out:
# 'mp3'

# %% [markdown]
# 3. Save the remaining list of URLS to disk with the correct file extensions.

# %%
display_all(osfls.head())
# Out:
#       clip_id organization                                  project  \
# 3646     3646           BU  ARU Test Project Model Comparisons 2021
# 3696     3696           BU  ARU Test Project Model Comparisons 2021
# 3740     3740           BU  ARU Test Project Model Comparisons 2021
# 3759     3759           BU  ARU Test Project Model Comparisons 2021
# 3877     3877           BU  ARU Test Project Model Comparisons 2021
#
#       project_id     location  location_id  recording_date_time  recording_id  \
# 3646        1099  ATP-FLB-14A       238593  2021-06-28 06:00:00        366621
# 3696        1099  ATP-FLB-14A       238593  2021-07-02 05:00:00        366633
# 3740        1099  ATP-FLB-14A       238593  2021-07-02 06:00:00        366638
# 3759        1099  ATP-FLB-14B       238600  2021-06-28 05:00:00        366610
# 3877        1099  ATP-FLB-14B       238600  2021-07-02 05:00:00        366631
#
#      task_method  task_id aru_task_status species_code  \
# 3646        1SPM   343288     Transcribed         OSFL
# 3696        1SPM   343300     Transcribed         OSFL
# 3740        1SPM   343305     Transcribed         OSFL
# 3759        1SPM   343277     Transcribed         OSFL
# 3877        1SPM   343298     Transcribed         OSFL
#
#          species_common_name species_scientific_name species_class  \
# 3646  Olive-sided Flycatcher        CONTOPUS COOPERI          Aves
# 3696  Olive-sided Flycatcher        CONTOPUS COOPERI          Aves
# 3740  Olive-sided Flycatcher        CONTOPUS COOPERI          Aves
# 3759  Olive-sided Flycatcher        CONTOPUS COOPERI          Aves
# 3877  Olive-sided Flycatcher        CONTOPUS COOPERI          Aves
#
#       detection_time  task_duration  tag_duration min_tag_freq max_tag_freq  \
# 3646          117.83          180.0          1.54      1.03kHz      5.14kHz
# 3696            0.29          180.0          1.58      1.59kHz      4.90kHz
# 3740          126.36          180.0          1.00      2.05kHz      3.78kHz
# 3759           41.15          180.0          1.63      1.63kHz      5.51kHz
# 3877            0.05          180.0          0.76      2.16kHz      4.48kHz
#
#        tag_id  individual_order vocalization abundance  tag_rating  \
# 3646  2748897               1.0         Song         1         NaN
# 3696  2744797               1.0         Song         1         NaN
# 3740  2748907               2.0         Song         1         NaN
# 3759  2746867               1.0         Song         1         NaN
# 3877  3445098               1.0         Song         1         NaN
#
#      tag_is_verified  clip_channel_used        observer  observer_user_id  \
# 3646               f                1.0  Marcus Sommers            1224.0
# 3696               f                2.0      Steve Enid             660.0
# 3740               f                2.0     Kelsey Bell            1242.0
# 3759               f                1.0      Steve Enid             660.0
# 3877               f                1.0   Lucas Wessner            2164.0
#
#       verifier_user_id  left_full_freq_tag_rms_peak_dbfs  \
# 3646               NaN                            -35.81
# 3696               NaN                            -35.45
# 3740               NaN                            -32.35
# 3759               NaN                            -22.89
# 3877               NaN                            -23.02
#
#       left_full_freq_tag_rms_trough_dbfs  left_full_freq_tag_pk_count  \
# 3646                              -38.45                          2.0
# 3696                              -38.60                          3.0
# 3740                              -39.48                          2.0
# 3759                              -22.95                          2.0
# 3877                              -25.97                          2.0
#
#       left_full_freq_tag_dc_offset  left_full_freq_tag_min_level  \
# 3646                      0.013525                      0.002960
# 3696                      0.013311                     -0.001526
# 3740                      0.013461                     -0.017395
# 3759                     -0.071428                     -0.076202
# 3877                     -0.070495                     -0.077545
#
#       left_full_freq_tag_max_level  left_full_freq_tag_peak_level_dbfs  \
# 3646                      0.024292                              -32.29
# 3696                      0.028931                              -30.77
# 3740                      0.038757                              -28.23
# 3759                     -0.066406                              -22.36
# 3877                     -0.044800                              -22.21
#
#       left_freq_filter_tag_rms_peak_dbfs  \
# 3646                              -52.74
# 3696                              -63.31
# 3740                              -71.09
# 3759                              -58.90
# 3877                              -61.41
#
#       left_freq_filter_tag_rms_trough_dbfs  left_freq_filter_tag_pk_count  \
# 3646                                -68.22                            2.0
# 3696                                -67.90                            2.0
# 3740                                -73.78                            2.0
# 3759                                -66.70                            2.0
# 3877                                -69.21                            2.0
#
#       left_freq_filter_tag_dc_offset  left_freq_filter_tag_min_level  \
# 3646                       -0.000001                       -0.005737
# 3696                        0.000000                       -0.005219
# 3740                        0.000000                       -0.001617
# 3759                        0.000002                       -0.006744
# 3877                        0.000002                       -0.009644
#
#       left_freq_filter_tag_max_level  left_freq_filter_tag_peak_level_dbfs  \
# 3646                        0.005890                                -44.60
# 3696                        0.002075                                -45.65
# 3740                        0.001678                                -55.50
# 3759                        0.024139                                -32.35
# 3877                        0.015717                                -36.07
#
#       right_full_freq_tag_rms_peak_dbfs  right_full_freq_tag_rms_trough_dbfs  \
# 3646                             -45.89                               -52.40
# 3696                             -44.78                               -51.87
# 3740                             -35.08                               -44.52
# 3759                             -25.76                               -25.82
# 3877                                NaN                                  NaN
#
#       right_full_freq_tag_pk_count  right_full_freq_tag_dc_offset  \
# 3646                           2.0                       0.002683
# 3696                           2.0                       0.002186
# 3740                           2.0                       0.002601
# 3759                           4.0                      -0.051322
# 3877                           NaN                            NaN
#
#       right_full_freq_tag_min_level  right_full_freq_tag_max_level  \
# 3646                      -0.005341                       0.012024
# 3696                      -0.009827                       0.014099
# 3740                      -0.024017                       0.034393
# 3759                      -0.055420                      -0.047180
# 3877                            NaN                            NaN
#
#       right_full_freq_tag_peak_level_dbfs  \
# 3646                               -38.40
# 3696                               -37.02
# 3740                               -29.27
# 3759                               -25.13
# 3877                                  NaN
#
#       right_freq_filter_tag_rms_peak_dbfs  \
# 3646                               -58.97
# 3696                               -64.91
# 3740                               -71.54
# 3759                               -61.10
# 3877                                  NaN
#
#       right_freq_filter_tag_rms_trough_dbfs  right_freq_filter_tag_pk_count  \
# 3646                                 -70.68                             2.0
# 3696                                 -70.18                             2.0
# 3740                                 -75.24                             2.0
# 3759                                 -67.13                             2.0
# 3877                                    NaN                             NaN
#
#       right_freq_filter_tag_dc_offset  right_freq_filter_tag_min_level  \
# 3646                         0.000000                        -0.003204
# 3696                         0.000000                        -0.002167
# 3740                         0.000000                        -0.002899
# 3759                         0.000001                        -0.005646
# 3877                              NaN                              NaN
#
#       right_freq_filter_tag_max_level  right_freq_filter_tag_peak_level_dbfs  \
# 3646                         0.003113                                 -49.89
# 3696                         0.002563                                 -51.82
# 3740                         0.002167                                 -50.75
# 3759                         0.017609                                 -35.09
# 3877                              NaN                                    NaN
#
#      tagged_in_wildtrax                                                url  \
# 3646                  t  https://portal.wildtrax.ca/home/aru-tasks/reco...
# 3696                  t  https://portal.wildtrax.ca/home/aru-tasks/reco...
# 3740                  t  https://portal.wildtrax.ca/home/aru-tasks/reco...
# 3759                  t  https://portal.wildtrax.ca/home/aru-tasks/reco...
# 3877                  t  https://portal.wildtrax.ca/home/aru-tasks/reco...
#
#                                     tag_spectrogram_url  \
# 3646  https://wildtrax-aru.s3.us-west-2.amazonaws.co...
# 3696  https://wildtrax-aru.s3.us-west-2.amazonaws.co...
# 3740  https://wildtrax-aru.s3.us-west-2.amazonaws.co...
# 3759  https://wildtrax-aru.s3.us-west-2.amazonaws.co...
# 3877  https://wildtrax-aru.s3.us-west-2.amazonaws.co...
#
#                                                clip_url sensorId  tasks  \
# 3646  https://wildtrax-aru.s3.us-west-2.amazonaws.co...      ARU    212
# 3696  https://wildtrax-aru.s3.us-west-2.amazonaws.co...      ARU    212
# 3740  https://wildtrax-aru.s3.us-west-2.amazonaws.co...      ARU    212
# 3759  https://wildtrax-aru.s3.us-west-2.amazonaws.co...      ARU    212
# 3877  https://wildtrax-aru.s3.us-west-2.amazonaws.co...      ARU    212
#
#       status  clip_index file_type
# 3646  Active        3646       mp3
# 3696  Active        3696       mp3
# 3740  Active        3740       mp3
# 3759  Active        3759       mp3
# 3877  Active        3877      flac

# %% [markdown]
# # Download a bunch of clips, without duplicating the download if a file with the same name already exists.
# - Use relative paths so that the downloader will work on other operating systems within different absolute directories.
# - Loop through all of the clip URLs and build a filename from the recording ID, the clip index and the file type.
# - If a recording with this filename already exists, skip the recording. We already downloaded audio from this recording. This will enble the program to re-run at a future date if the download gets interrupted or if there are more files to add to the directory.

# %%
def exists(fname):
    '''
    check to see whether a file exists
    '''
    return Path.exists(fname)

# %% [markdown]
# # Downloader

# %%
rec_path = Path.joinpath(data_path, 'raw/recordings')
skipped_files = 0

for i in (osfls.index):
    clip_url = osfls.clip_url[i]
    extension = osfls.file_type[i]
    file = Path.joinpath(rec_path, f'recording-{osfls.recording_id[i]}-clip-{i}.{extension}')
    
    if exists(file):
        skipped_files += 1
    else:
        r = requests.get(clip_url)
        with open(file, 'wb') as f:
            f.write(r.content)
print(f'skipped {skipped_files} previously downloaded files')
# Out:
# skipped 5163 previously downloaded files

# %%
osfls.to_pickle(data_path/'processed/osfls')
