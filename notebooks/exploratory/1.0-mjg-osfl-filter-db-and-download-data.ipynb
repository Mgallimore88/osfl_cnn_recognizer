# %% [markdown]
# # Data Downloader and cleaner
# This notebook develops a method to clean the database and download data

# %% [markdown]
# `meta` refers to the metadata of the audio clips, and is read from TrainingData_BU&Public_CWS.csv
#
# Operations performed:
# - Remove samples with abundance labels 'too many to tag'
# - Include only vocalizations with type 'song'
# - Vocalizations tagged outside of wildtrax aren't included since the start and end times can be inaccurate.
# - The 'tag_rating' field has been left unfiltered.
# - Only olive-sided flycatcher vocalizations are included.
# - Convert Id fields from float type to int type using pd.astype()
# - Some clips in the .csv file don't have a url to the audio data. These are skipped.
# <br>
#
# Todo:
# - Check to make sure that tags with a different tag id but the same recording id do actually refer to the same recording - and not just duplicated recording ids for different recordings.

# %%
import pandas as pd
import requests
import re
from pathlib import Path

# %%
data_path = Path('../../data/raw/')
# Out:
# PosixPath('../../data/raw')

# %%
meta = pd.read_csv(data_path/'TrainingData_BU&Public_CWS.csv')
# Out:
# /var/folders/hy/36n7jr6x3h74ddx507dc12_00000gn/T/ipykernel_47988/2033733313.py:1: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   meta = pd.read_csv(data_path/'TrainingData_BU&Public_CWS.csv')

# %%
len(meta)
# Out:
# 1152840

# %%
def display_all(df, rows=10, cols=200):
    with pd.option_context("display.max_columns", cols):
           display(df)

# %% [markdown]
# # Clean the data

# %% [markdown]
# One of the entries in the .csv file didn't contain Id tags. Remove this from the dataset

# %%
meta.drop(index=1152839, inplace=True)

# %%
# convert ids to integer types
meta.recording_id = meta.recording_id.astype(int)
meta.location_id = meta.location_id.astype(int)
meta.task_id = meta.task_id.astype(int)
meta.tag_id = meta.tag_id.astype(int)

# %% [markdown]
# Some of the abundance types are stored as strings and some are numeric. Convert all to same type.

# %%
meta.abundance = meta.abundance.astype(str)

# %%
display_all(meta.head())
# Out:
#   organization             project  project_id     location  location_id  \
# 0           BU  Alberta Archetypes        1501  BBS-4139-20        87850
# 1           BU  Alberta Archetypes        1501  BBS-4139-27        87844
# 2           BU  Alberta Archetypes        1501  BBS-4139-28        87842
# 3           BU  Alberta Archetypes        1501  BBS-4139-28        87842
# 4           BU  Alberta Archetypes        1501  BBS-4139-36        87834
#
#    recording_date_time  recording_id task_method  task_id aru_task_status  \
# 0  2021-07-03 06:56:02        331758        None   595843     Transcribed
# 1  2021-07-03 07:42:01        331765        None   595844     Transcribed
# 2  2021-07-03 07:47:01        331764        None   595845     Transcribed
# 3  2021-07-03 07:47:01        331764        None   595845     Transcribed
# 4  2022-06-26 08:24:04        358620        None   595846     Transcribed
#
#   species_code species_common_name    species_scientific_name species_class  \
# 0         SAVS    Savannah Sparrow  PASSERCULUS SANDWICHENSIS          Aves
# 1         SAVS    Savannah Sparrow  PASSERCULUS SANDWICHENSIS          Aves
# 2         SAVS    Savannah Sparrow  PASSERCULUS SANDWICHENSIS          Aves
# 3         SAVS    Savannah Sparrow  PASSERCULUS SANDWICHENSIS          Aves
# 4         OVEN            Ovenbird        SEIURUS AUROCAPILLA          Aves
#
#    detection_time  task_duration  tag_duration min_tag_freq max_tag_freq  \
# 0           10.74          180.0          2.51      2.01kHz     10.09kHz
# 1           20.35          180.0          2.51      2.29kHz     10.32kHz
# 2            7.18          180.0          2.51      2.19kHz     10.79kHz
# 3           71.73          180.0          2.51      1.63kHz     10.65kHz
# 4            2.75          180.0          2.57      2.16kHz     10.92kHz
#
#     tag_id  individual_order vocalization abundance  tag_rating  \
# 0  3212033               1.0         Song         1         NaN
# 1  3212034               1.0         Song         1         NaN
# 2  3212035               1.0         Song         1         NaN
# 3  3212036               1.0         Song         1         NaN
# 4  3212037               1.0         Song         1         NaN
#
#   tag_is_verified  clip_channel_used      observer  observer_user_id  \
# 0               f                1.0  Not Assigned              -1.0
# 1               f                1.0  Not Assigned              -1.0
# 2               f                1.0  Not Assigned              -1.0
# 3               f                1.0  Not Assigned              -1.0
# 4               f                1.0  Not Assigned              -1.0
#
#    verifier_user_id  left_full_freq_tag_rms_peak_dbfs  \
# 0               NaN                            -41.64
# 1               NaN                            -22.50
# 2               NaN                            -23.62
# 3               NaN                            -15.98
# 4               NaN                            -36.45
#
#    left_full_freq_tag_rms_trough_dbfs  left_full_freq_tag_pk_count  \
# 0                              -55.62                          2.0
# 1                              -39.54                          2.0
# 2                              -52.42                          2.0
# 3                              -28.24                          2.0
# 4                              -50.15                          2.0
#
#    left_full_freq_tag_dc_offset  left_full_freq_tag_min_level  \
# 0                     -0.000014                     -0.020752
# 1                     -0.000087                     -0.137454
# 2                      0.000045                     -0.149939
# 3                     -0.000270                     -0.317960
# 4                     -0.000026                     -0.041443
#
#    left_full_freq_tag_max_level  left_full_freq_tag_peak_level_dbfs  \
# 0                      0.017666                              -33.66
# 1                      0.144287                              -16.82
# 2                      0.135607                              -16.48
# 3                      0.371485                               -8.60
# 4                      0.051636                              -25.74
#
#    left_freq_filter_tag_rms_peak_dbfs  left_freq_filter_tag_rms_trough_dbfs  \
# 0                              -42.32                                -67.30
# 1                              -41.80                                -64.05
# 2                              -51.09                                -66.13
# 3                              -46.94                                -65.00
# 4                              -40.94                                -57.32
#
#    left_freq_filter_tag_pk_count  left_freq_filter_tag_dc_offset  \
# 0                            2.0                             0.0
# 1                            2.0                             0.0
# 2                            2.0                             0.0
# 3                            2.0                             0.0
# 4                            2.0                             0.0
#
#    left_freq_filter_tag_min_level  left_freq_filter_tag_max_level  \
# 0                       -0.016110                        0.016191
# 1                       -0.036974                        0.035904
# 2                       -0.007927                        0.008014
# 3                       -0.013312                        0.013227
# 4                       -0.033356                        0.035675
#
#    left_freq_filter_tag_peak_level_dbfs  right_full_freq_tag_rms_peak_dbfs  \
# 0                                -35.81                                NaN
# 1                                -28.64                                NaN
# 2                                -41.92                                NaN
# 3                                -37.52                                NaN
# 4                                -28.95                                NaN
#
#    right_full_freq_tag_rms_trough_dbfs  right_full_freq_tag_pk_count  \
# 0                                  NaN                           NaN
# 1                                  NaN                           NaN
# 2                                  NaN                           NaN
# 3                                  NaN                           NaN
# 4                                  NaN                           NaN
#
#    right_full_freq_tag_dc_offset  right_full_freq_tag_min_level  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    right_full_freq_tag_max_level  right_full_freq_tag_peak_level_dbfs  \
# 0                            NaN                                  NaN
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                            NaN                                  NaN
#
#    right_freq_filter_tag_rms_peak_dbfs  right_freq_filter_tag_rms_trough_dbfs  \
# 0                                  NaN                                    NaN
# 1                                  NaN                                    NaN
# 2                                  NaN                                    NaN
# 3                                  NaN                                    NaN
# 4                                  NaN                                    NaN
#
#    right_freq_filter_tag_pk_count  right_freq_filter_tag_dc_offset  \
# 0                             NaN                              NaN
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
#
#    right_freq_filter_tag_min_level  right_freq_filter_tag_max_level  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    right_freq_filter_tag_peak_level_dbfs tagged_in_wildtrax  \
# 0                                    NaN                  f
# 1                                    NaN                  f
# 2                                    NaN                  f
# 3                                    NaN                  f
# 4                                    NaN                  f
#
#                                                  url  \
# 0  https://portal.wildtrax.ca/home/aru-tasks/reco...
# 1  https://portal.wildtrax.ca/home/aru-tasks/reco...
# 2  https://portal.wildtrax.ca/home/aru-tasks/reco...
# 3  https://portal.wildtrax.ca/home/aru-tasks/reco...
# 4  https://portal.wildtrax.ca/home/aru-tasks/reco...
#
#                                  tag_spectrogram_url  \
# 0  https://wildtrax-aru.s3.us-west-2.amazonaws.co...
# 1  https://wildtrax-aru.s3.us-west-2.amazonaws.co...
# 2  https://wildtrax-aru.s3.us-west-2.amazonaws.co...
# 3  https://wildtrax-aru.s3.us-west-2.amazonaws.co...
# 4  https://wildtrax-aru.s3.us-west-2.amazonaws.co...
#
#                                             clip_url sensorId  tasks  status
# 0  https://wildtrax-aru.s3.us-west-2.amazonaws.co...      ARU    357  Active
# 1  https://wildtrax-aru.s3.us-west-2.amazonaws.co...      ARU    357  Active
# 2  https://wildtrax-aru.s3.us-west-2.amazonaws.co...      ARU    357  Active
# 3  https://wildtrax-aru.s3.us-west-2.amazonaws.co...      ARU    357  Active
# 4  https://wildtrax-aru.s3.us-west-2.amazonaws.co...      ARU    357  Active

# %%
meta.abundance.value_counts()
# Out:
# 1       1024057
# nan       49875
# TMTT      40077
# CI 1      17247
# CI 3      11324
# CI 2       8411
# 2          1167
# 3           342
# 5           126
# 4           125
# 6            36
# 7            28
# 8            14
# 10            9
# 9             1
# Name: abundance, dtype: int64

# %%
# Drop tmtt abundance tags.
tmtt_idxs = meta[meta.abundance=='TMTT'].index
meta.drop(tmtt_idxs, inplace=True)

# %%
# Drop non song vocalizations
not_song_idxs = meta[meta.vocalization!='Song'].index
meta.drop(not_song_idxs, inplace=True)

# %%
# Drop recordings not labeled in wildtrax
labeled_elsewhere_idxs = meta[meta.tagged_in_wildtrax=='f'].index
meta.drop(labeled_elsewhere_idxs, inplace=True)

# %%
# choose OSFL entries
osfl_idxs = meta[meta.species_code=='OSFL'].index
osfls = meta.loc[osfl_idxs]

# %% [markdown]
# Add a column named `file_type` to the dataframe. This is done only to samples with a clip_url.

# %%
osfls['file_type'] = None
for idx in osfls[~osfls.clip_url.isna()].index:
    
    osfls['file_type'][idx] = osfls['clip_url'][idx].split('.')[-1]
# Out:
# /var/folders/hy/36n7jr6x3h74ddx507dc12_00000gn/T/ipykernel_47988/3830306749.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   osfls['file_type'][idx] = osfls['clip_url'][idx].split('.')[-1]

# %% [markdown]
# See how the file_type has been added to the meta dataframe as well as the osfls dataframe to understand why the error message above was generated.

# %%
meta.head()
# Out:
#     organization                         project  project_id    location  \
# 382           BU              Alberta Archetypes        1501   P-E0-1-10
# 425           BU  Amplitude Quality Testing 2020         293  AM-403-SE2
# 427           BU  Amplitude Quality Testing 2020         293  AM-403-SE2
# 428           BU  Amplitude Quality Testing 2020         293  AM-403-SE2
# 429           BU  Amplitude Quality Testing 2020         293  AM-403-SE2
#
#      location_id  recording_date_time  recording_id task_method  task_id  \
# 382       308678  2022-06-05 06:51:00        416962        None   596169
# 425        36043  2017-06-15 04:46:00         92051        None    87956
# 427        36043  2017-06-15 04:46:00         92051        None    87898
# 428        36043  2017-06-15 04:46:00         92051        None    87840
# 429        36043  2017-06-15 04:46:00         92051        None    87927
#
#     aru_task_status  ... right_freq_filter_tag_min_level  \
# 382     Transcribed  ...                             NaN
# 425     Transcribed  ...                       -0.069424
# 427     Transcribed  ...                       -0.040386
# 428     Transcribed  ...                       -0.064721
# 429     Transcribed  ...                       -0.037280
#
#     right_freq_filter_tag_max_level right_freq_filter_tag_peak_level_dbfs  \
# 382                             NaN                                   NaN
# 425                        0.063139                                -23.17
# 427                        0.036900                                -27.88
# 428                        0.062714                                -23.78
# 429                        0.040078                                -27.94
#
#     tagged_in_wildtrax                                                url  \
# 382                  t  https://portal.wildtrax.ca/home/aru-tasks/reco...
# 425                  t  https://portal.wildtrax.ca/home/aru-tasks/reco...
# 427                  t  https://portal.wildtrax.ca/home/aru-tasks/reco...
# 428                  t  https://portal.wildtrax.ca/home/aru-tasks/reco...
# 429                  t  https://portal.wildtrax.ca/home/aru-tasks/reco...
#
#                                    tag_spectrogram_url  \
# 382  https://wildtrax-aru.s3.us-west-2.amazonaws.co...
# 425  https://wildtrax-aru.s3.us-west-2.amazonaws.co...
# 427  https://wildtrax-aru.s3.us-west-2.amazonaws.co...
# 428  https://wildtrax-aru.s3.us-west-2.amazonaws.co...
# 429  https://wildtrax-aru.s3.us-west-2.amazonaws.co...
#
#                                               clip_url sensorId tasks  \
# 382  https://wildtrax-aru.s3.us-west-2.amazonaws.co...      ARU   357
# 425  https://wildtrax-aru.s3.us-west-2.amazonaws.co...      ARU   174
# 427  https://wildtrax-aru.s3.us-west-2.amazonaws.co...      ARU   174
# 428  https://wildtrax-aru.s3.us-west-2.amazonaws.co...      ARU   174
# 429  https://wildtrax-aru.s3.us-west-2.amazonaws.co...      ARU   174
#
#                   status
# 382               Active
# 425  Published - Private
# 427  Published - Private
# 428  Published - Private
# 429  Published - Private
#
# [5 rows x 64 columns]

# %% [markdown]
# # drop entries with a missing clip_url field from OSFLs

# %%
len(osfls)
# Out:
# 5167

# %%
osfls.drop(osfls.loc[osfls.clip_url.isna()].index, inplace=True)

# %%
len(osfls)
# Out:
# 5163

# %% [markdown]
# # Download the audio samples

# %% [markdown]
# 1. Get the URL from the database (example)

# %%
url = osfls.clip_url.iloc[0]

# %%
url
# Out:
# 'https://wildtrax-aru.s3.us-west-2.amazonaws.com/df7f6bdc-9300-4738-9ddb-81d84d448400/687a4de556e1439fa624365426dcb3b0.mp3'

# %% [markdown]
# 2. Extract the file type from the url (example)

# %%
url.split('.')[-1]
# Out:
# 'mp3'

# %% [markdown]
# 3. Save the remaining list of URLS to disk with the correct file extensions.

# %%
display_all(osfls.head())
# Out:
#      organization                                  project  project_id  \
# 3646           BU  ARU Test Project Model Comparisons 2021        1099
# 3696           BU  ARU Test Project Model Comparisons 2021        1099
# 3740           BU  ARU Test Project Model Comparisons 2021        1099
# 3759           BU  ARU Test Project Model Comparisons 2021        1099
# 3877           BU  ARU Test Project Model Comparisons 2021        1099
#
#          location  location_id  recording_date_time  recording_id task_method  \
# 3646  ATP-FLB-14A       238593  2021-06-28 06:00:00        366621        1SPM
# 3696  ATP-FLB-14A       238593  2021-07-02 05:00:00        366633        1SPM
# 3740  ATP-FLB-14A       238593  2021-07-02 06:00:00        366638        1SPM
# 3759  ATP-FLB-14B       238600  2021-06-28 05:00:00        366610        1SPM
# 3877  ATP-FLB-14B       238600  2021-07-02 05:00:00        366631        1SPM
#
#       task_id aru_task_status species_code     species_common_name  \
# 3646   343288     Transcribed         OSFL  Olive-sided Flycatcher
# 3696   343300     Transcribed         OSFL  Olive-sided Flycatcher
# 3740   343305     Transcribed         OSFL  Olive-sided Flycatcher
# 3759   343277     Transcribed         OSFL  Olive-sided Flycatcher
# 3877   343298     Transcribed         OSFL  Olive-sided Flycatcher
#
#      species_scientific_name species_class  detection_time  task_duration  \
# 3646        CONTOPUS COOPERI          Aves          117.83          180.0
# 3696        CONTOPUS COOPERI          Aves            0.29          180.0
# 3740        CONTOPUS COOPERI          Aves          126.36          180.0
# 3759        CONTOPUS COOPERI          Aves           41.15          180.0
# 3877        CONTOPUS COOPERI          Aves            0.05          180.0
#
#       tag_duration min_tag_freq max_tag_freq   tag_id  individual_order  \
# 3646          1.54      1.03kHz      5.14kHz  2748897               1.0
# 3696          1.58      1.59kHz      4.90kHz  2744797               1.0
# 3740          1.00      2.05kHz      3.78kHz  2748907               2.0
# 3759          1.63      1.63kHz      5.51kHz  2746867               1.0
# 3877          0.76      2.16kHz      4.48kHz  3445098               1.0
#
#      vocalization abundance  tag_rating tag_is_verified  clip_channel_used  \
# 3646         Song         1         NaN               f                1.0
# 3696         Song         1         NaN               f                2.0
# 3740         Song         1         NaN               f                2.0
# 3759         Song         1         NaN               f                1.0
# 3877         Song         1         NaN               f                1.0
#
#             observer  observer_user_id  verifier_user_id  \
# 3646  Marcus Sommers            1224.0               NaN
# 3696      Steve Enid             660.0               NaN
# 3740     Kelsey Bell            1242.0               NaN
# 3759      Steve Enid             660.0               NaN
# 3877   Lucas Wessner            2164.0               NaN
#
#       left_full_freq_tag_rms_peak_dbfs  left_full_freq_tag_rms_trough_dbfs  \
# 3646                            -35.81                              -38.45
# 3696                            -35.45                              -38.60
# 3740                            -32.35                              -39.48
# 3759                            -22.89                              -22.95
# 3877                            -23.02                              -25.97
#
#       left_full_freq_tag_pk_count  left_full_freq_tag_dc_offset  \
# 3646                          2.0                      0.013525
# 3696                          3.0                      0.013311
# 3740                          2.0                      0.013461
# 3759                          2.0                     -0.071428
# 3877                          2.0                     -0.070495
#
#       left_full_freq_tag_min_level  left_full_freq_tag_max_level  \
# 3646                      0.002960                      0.024292
# 3696                     -0.001526                      0.028931
# 3740                     -0.017395                      0.038757
# 3759                     -0.076202                     -0.066406
# 3877                     -0.077545                     -0.044800
#
#       left_full_freq_tag_peak_level_dbfs  left_freq_filter_tag_rms_peak_dbfs  \
# 3646                              -32.29                              -52.74
# 3696                              -30.77                              -63.31
# 3740                              -28.23                              -71.09
# 3759                              -22.36                              -58.90
# 3877                              -22.21                              -61.41
#
#       left_freq_filter_tag_rms_trough_dbfs  left_freq_filter_tag_pk_count  \
# 3646                                -68.22                            2.0
# 3696                                -67.90                            2.0
# 3740                                -73.78                            2.0
# 3759                                -66.70                            2.0
# 3877                                -69.21                            2.0
#
#       left_freq_filter_tag_dc_offset  left_freq_filter_tag_min_level  \
# 3646                       -0.000001                       -0.005737
# 3696                        0.000000                       -0.005219
# 3740                        0.000000                       -0.001617
# 3759                        0.000002                       -0.006744
# 3877                        0.000002                       -0.009644
#
#       left_freq_filter_tag_max_level  left_freq_filter_tag_peak_level_dbfs  \
# 3646                        0.005890                                -44.60
# 3696                        0.002075                                -45.65
# 3740                        0.001678                                -55.50
# 3759                        0.024139                                -32.35
# 3877                        0.015717                                -36.07
#
#       right_full_freq_tag_rms_peak_dbfs  right_full_freq_tag_rms_trough_dbfs  \
# 3646                             -45.89                               -52.40
# 3696                             -44.78                               -51.87
# 3740                             -35.08                               -44.52
# 3759                             -25.76                               -25.82
# 3877                                NaN                                  NaN
#
#       right_full_freq_tag_pk_count  right_full_freq_tag_dc_offset  \
# 3646                           2.0                       0.002683
# 3696                           2.0                       0.002186
# 3740                           2.0                       0.002601
# 3759                           4.0                      -0.051322
# 3877                           NaN                            NaN
#
#       right_full_freq_tag_min_level  right_full_freq_tag_max_level  \
# 3646                      -0.005341                       0.012024
# 3696                      -0.009827                       0.014099
# 3740                      -0.024017                       0.034393
# 3759                      -0.055420                      -0.047180
# 3877                            NaN                            NaN
#
#       right_full_freq_tag_peak_level_dbfs  \
# 3646                               -38.40
# 3696                               -37.02
# 3740                               -29.27
# 3759                               -25.13
# 3877                                  NaN
#
#       right_freq_filter_tag_rms_peak_dbfs  \
# 3646                               -58.97
# 3696                               -64.91
# 3740                               -71.54
# 3759                               -61.10
# 3877                                  NaN
#
#       right_freq_filter_tag_rms_trough_dbfs  right_freq_filter_tag_pk_count  \
# 3646                                 -70.68                             2.0
# 3696                                 -70.18                             2.0
# 3740                                 -75.24                             2.0
# 3759                                 -67.13                             2.0
# 3877                                    NaN                             NaN
#
#       right_freq_filter_tag_dc_offset  right_freq_filter_tag_min_level  \
# 3646                         0.000000                        -0.003204
# 3696                         0.000000                        -0.002167
# 3740                         0.000000                        -0.002899
# 3759                         0.000001                        -0.005646
# 3877                              NaN                              NaN
#
#       right_freq_filter_tag_max_level  right_freq_filter_tag_peak_level_dbfs  \
# 3646                         0.003113                                 -49.89
# 3696                         0.002563                                 -51.82
# 3740                         0.002167                                 -50.75
# 3759                         0.017609                                 -35.09
# 3877                              NaN                                    NaN
#
#      tagged_in_wildtrax                                                url  \
# 3646                  t  https://portal.wildtrax.ca/home/aru-tasks/reco...
# 3696                  t  https://portal.wildtrax.ca/home/aru-tasks/reco...
# 3740                  t  https://portal.wildtrax.ca/home/aru-tasks/reco...
# 3759                  t  https://portal.wildtrax.ca/home/aru-tasks/reco...
# 3877                  t  https://portal.wildtrax.ca/home/aru-tasks/reco...
#
#                                     tag_spectrogram_url  \
# 3646  https://wildtrax-aru.s3.us-west-2.amazonaws.co...
# 3696  https://wildtrax-aru.s3.us-west-2.amazonaws.co...
# 3740  https://wildtrax-aru.s3.us-west-2.amazonaws.co...
# 3759  https://wildtrax-aru.s3.us-west-2.amazonaws.co...
# 3877  https://wildtrax-aru.s3.us-west-2.amazonaws.co...
#
#                                                clip_url sensorId  tasks  \
# 3646  https://wildtrax-aru.s3.us-west-2.amazonaws.co...      ARU    212
# 3696  https://wildtrax-aru.s3.us-west-2.amazonaws.co...      ARU    212
# 3740  https://wildtrax-aru.s3.us-west-2.amazonaws.co...      ARU    212
# 3759  https://wildtrax-aru.s3.us-west-2.amazonaws.co...      ARU    212
# 3877  https://wildtrax-aru.s3.us-west-2.amazonaws.co...      ARU    212
#
#       status file_type
# 3646  Active       mp3
# 3696  Active       mp3
# 3740  Active       mp3
# 3759  Active       mp3
# 3877  Active      flac

# %% [markdown]
# # Download a bunch of clips, without duplicating the download if a file with the same name already exists.
# - Use relative paths so that the downloader will work on other operating systems within different absolute directories.
# - Loop through all of the clip URLs and build a filename from the recording ID and the file type.
# - If a recording with this ID already exists, skip the recording. We already downloaded audio from this recording.
# - Check this assumption in future - it could be the case that these are short clips of audio taken from longer recordings where the longer recordings have unique ids but the clips are all different.

# %%
def exists(fname):
    '''
    check to see whether a file exists
    '''
    return Path.exists(fname)

# %%
rec_path = Path.joinpath(data_path, 'recordings')

for rec in (osfls.index):
    clip_url = osfls.clip_url[rec]
    ext = osfls.file_type[rec]
    file = Path.joinpath(rec_path, str(osfls.recording_id[rec]) + '.' + ext)
    
    if exists(file):
        print(f'{file} already downloaded')
    else:
        r = requests.get(clip_url)
        with open(file, 'wb') as f:
            f.write(r.content)
# Out:
# ../../data/raw/recordings/366621.mp3 already downloaded
# ../../data/raw/recordings/366633.mp3 already downloaded
# ../../data/raw/recordings/366638.mp3 already downloaded
# ../../data/raw/recordings/366610.mp3 already downloaded
# ../../data/raw/recordings/366631.flac already downloaded
# ../../data/raw/recordings/366624.mp3 already downloaded
# ../../data/raw/recordings/366624.mp3 already downloaded
# ../../data/raw/recordings/366618.flac already downloaded
# ../../data/raw/recordings/366627.mp3 already downloaded
# ../../data/raw/recordings/366637.mp3 already downloaded
# ../../data/raw/recordings/366637.mp3 already downloaded
# ../../data/raw/recordings/366643.flac already downloaded
# ../../data/raw/recordings/366643.flac already downloaded
# ../../data/raw/recordings/366643.flac already downloaded
# ../../data/raw/recordings/366643.flac already downloaded
# ../../data/raw/recordings/366643.flac already downloaded
# ../../data/raw/recordings/366614.mp3 already downloaded
# ../../data/raw/recordings/366614.mp3 already downloaded
# ../../data/raw/recordings/366626.flac already downloaded
# ../../data/raw/recordings/366635.mp3 already downloaded
# ../../data/raw/recordings/366635.mp3 already downloaded
# ../../data/raw/recordings/366635.mp3 already downloaded
# ../../data/raw/recordings/366639.mp3 already downloaded
# ../../data/raw/recordings/366639.mp3 already downloaded
# ../../data/raw/recordings/255472.mp3 already downloaded
# ../../data/raw/recordings/255412.mp3 already downloaded
# ../../data/raw/recordings/255913.mp3 already downloaded
# ../../data/raw/recordings/255913.mp3 already downloaded
# ../../data/raw/recordings/255913.mp3 already downloaded
# ../../data/raw/recordings/255913.mp3 already downloaded
# ../../data/raw/recordings/255913.mp3 already downloaded
# ../../data/raw/recordings/255913.mp3 already downloaded
# ../../data/raw/recordings/255913.mp3 already downloaded
# ../../data/raw/recordings/255913.mp3 already downloaded
# ../../data/raw/recordings/255913.mp3 already downloaded
# ../../data/raw/recordings/255913.mp3 already downloaded
# ../../data/raw/recordings/255913.mp3 already downloaded
# ../../data/raw/recordings/255913.mp3 already downloaded
# ../../data/raw/recordings/255913.mp3 already downloaded
# ../../data/raw/recordings/255913.mp3 already downloaded
# ../../data/raw/recordings/255913.mp3 already downloaded
# ../../data/raw/recordings/255913.mp3 already downloaded
# ../../data/raw/recordings/255913.mp3 already downloaded
# ../../data/raw/recordings/255913.mp3 already downloaded
# ../../data/raw/recordings/255938.mp3 already downloaded
# ../../data/raw/recordings/255938.mp3 already downloaded
# ../../data/raw/recordings/255938.mp3 already downloaded
# ../../data/raw/recordings/255938.mp3 already downloaded
# ../../data/raw/recordings/255938.mp3 already downloaded
# ../../data/raw/recordings/255938.mp3 already downloaded
# ../../data/raw/recordings/255940.mp3 already downloaded
# ../../data/raw/recordings/255949.mp3 already downloaded
# ../../data/raw/recordings/255949.mp3 already downloaded
# ../../data/raw/recordings/255967.mp3 already downloaded
# ../../data/raw/recordings/255967.mp3 already downloaded
# ../../data/raw/recordings/255967.mp3 already downloaded
# ../../data/raw/recordings/255967.mp3 already downloaded
# ../../data/raw/recordings/255967.mp3 already downloaded
# ../../data/raw/recordings/255967.mp3 already downloaded
# ../../data/raw/recordings/255967.mp3 already downloaded
# ../../data/raw/recordings/255967.mp3 already downloaded
# ../../data/raw/recordings/255967.mp3 already downloaded
# ../../data/raw/recordings/255967.mp3 already downloaded
# ../../data/raw/recordings/255967.mp3 already downloaded
# ../../data/raw/recordings/255967.mp3 already downloaded
# ../../data/raw/recordings/255967.mp3 already downloaded
# ../../data/raw/recordings/255967.flac already downloaded
# ../../data/raw/recordings/255980.mp3 already downloaded
# ../../data/raw/recordings/255980.mp3 already downloaded
# ../../data/raw/recordings/255980.mp3 already downloaded
# ../../data/raw/recordings/255980.mp3 already downloaded
# ../../data/raw/recordings/255980.mp3 already downloaded
# ../../data/raw/recordings/255420.mp3 already downloaded
# ../../data/raw/recordings/255419.mp3 already downloaded
# ../../data/raw/recordings/255419.mp3 already downloaded
# ../../data/raw/recordings/255421.mp3 already downloaded
# ../../data/raw/recordings/255421.mp3 already downloaded
# ../../data/raw/recordings/255421.mp3 already downloaded
# ../../data/raw/recordings/255421.mp3 already downloaded
# ../../data/raw/recordings/255431.mp3 already downloaded
# ../../data/raw/recordings/255431.mp3 already downloaded
# ../../data/raw/recordings/255432.mp3 already downloaded
# ../../data/raw/recordings/255432.mp3 already downloaded
# ../../data/raw/recordings/255432.mp3 already downloaded
# ../../data/raw/recordings/255433.mp3 already downloaded
# ../../data/raw/recordings/255433.mp3 already downloaded
# ../../data/raw/recordings/255449.mp3 already downloaded
# ../../data/raw/recordings/255449.mp3 already downloaded
# ../../data/raw/recordings/255449.mp3 already downloaded
# ../../data/raw/recordings/255449.mp3 already downloaded
# ../../data/raw/recordings/255449.mp3 already downloaded
# ../../data/raw/recordings/255456.mp3 already downloaded
# ../../data/raw/recordings/255454.mp3 already downloaded
# ../../data/raw/recordings/255454.mp3 already downloaded
# ../../data/raw/recordings/255454.mp3 already downloaded
# ../../data/raw/recordings/255454.mp3 already downloaded
# ../../data/raw/recordings/255454.mp3 already downloaded
# ../../data/raw/recordings/255454.mp3 already downloaded
# ../../data/raw/recordings/255454.mp3 already downloaded
# ../../data/raw/recordings/255454.mp3 already downloaded
# ../../data/raw/recordings/255454.mp3 already downloaded
# ../../data/raw/recordings/255454.mp3 already downloaded
# ../../data/raw/recordings/255454.mp3 already downloaded
# ../../data/raw/recordings/255454.mp3 already downloaded
# ../../data/raw/recordings/255454.mp3 already downloaded
# ../../data/raw/recordings/255454.mp3 already downloaded
# ../../data/raw/recordings/255454.mp3 already downloaded
# ../../data/raw/recordings/255454.mp3 already downloaded
# ../../data/raw/recordings/255454.mp3 already downloaded
# ../../data/raw/recordings/255454.mp3 already downloaded
# ../../data/raw/recordings/255454.mp3 already downloaded
# ../../data/raw/recordings/255454.mp3 already downloaded
# ../../data/raw/recordings/255454.mp3 already downloaded
# ../../data/raw/recordings/255454.mp3 already downloaded
# ../../data/raw/recordings/255454.mp3 already downloaded
# ../../data/raw/recordings/255454.mp3 already downloaded
# ../../data/raw/recordings/255454.mp3 already downloaded
# ../../data/raw/recordings/255454.mp3 already downloaded
# ../../data/raw/recordings/255454.mp3 already downloaded
# ../../data/raw/recordings/255457.mp3 already downloaded
# ../../data/raw/recordings/255457.mp3 already downloaded
# ../../data/raw/recordings/255457.mp3 already downloaded
# ../../data/raw/recordings/255457.mp3 already downloaded
# ../../data/raw/recordings/255457.mp3 already downloaded
# ../../data/raw/recordings/255457.mp3 already downloaded
# ../../data/raw/recordings/255457.mp3 already downloaded
# ../../data/raw/recordings/255457.mp3 already downloaded
# ../../data/raw/recordings/255457.mp3 already downloaded
# ../../data/raw/recordings/255457.mp3 already downloaded
# ../../data/raw/recordings/255457.mp3 already downloaded
# ../../data/raw/recordings/255457.mp3 already downloaded
# ../../data/raw/recordings/255457.mp3 already downloaded
# ../../data/raw/recordings/255457.mp3 already downloaded
# ../../data/raw/recordings/255457.mp3 already downloaded
# ../../data/raw/recordings/255457.mp3 already downloaded
# ../../data/raw/recordings/255457.mp3 already downloaded
# ../../data/raw/recordings/255457.mp3 already downloaded
# ../../data/raw/recordings/255457.mp3 already downloaded
# ../../data/raw/recordings/255457.mp3 already downloaded
# ../../data/raw/recordings/255457.mp3 already downloaded
# ../../data/raw/recordings/255457.mp3 already downloaded
# ../../data/raw/recordings/255457.mp3 already downloaded
# ../../data/raw/recordings/255457.mp3 already downloaded
# ../../data/raw/recordings/255457.mp3 already downloaded
# ../../data/raw/recordings/255457.mp3 already downloaded
# ../../data/raw/recordings/255457.mp3 already downloaded
# ../../data/raw/recordings/255457.mp3 already downloaded
# ../../data/raw/recordings/255457.mp3 already downloaded
# ../../data/raw/recordings/255457.mp3 already downloaded
# ../../data/raw/recordings/255461.mp3 already downloaded
# ../../data/raw/recordings/255465.mp3 already downloaded
# ../../data/raw/recordings/255465.mp3 already downloaded
# ../../data/raw/recordings/255465.mp3 already downloaded
# ../../data/raw/recordings/255539.mp3 already downloaded
# ../../data/raw/recordings/255539.mp3 already downloaded
# ../../data/raw/recordings/255539.mp3 already downloaded
# ../../data/raw/recordings/255539.mp3 already downloaded
# ../../data/raw/recordings/255539.mp3 already downloaded
# ../../data/raw/recordings/255539.mp3 already downloaded
# ../../data/raw/recordings/255539.mp3 already downloaded
# ../../data/raw/recordings/255539.mp3 already downloaded
# ../../data/raw/recordings/255544.mp3 already downloaded
# ../../data/raw/recordings/255544.mp3 already downloaded
# ../../data/raw/recordings/255544.mp3 already downloaded
# ../../data/raw/recordings/255544.mp3 already downloaded
# ../../data/raw/recordings/255544.mp3 already downloaded
# ../../data/raw/recordings/255544.mp3 already downloaded
# ../../data/raw/recordings/255544.mp3 already downloaded
# ../../data/raw/recordings/255544.mp3 already downloaded
# ../../data/raw/recordings/255544.mp3 already downloaded
# ../../data/raw/recordings/255544.mp3 already downloaded
# ../../data/raw/recordings/255544.mp3 already downloaded
# ../../data/raw/recordings/255544.mp3 already downloaded
# ../../data/raw/recordings/255544.mp3 already downloaded
# ../../data/raw/recordings/255544.mp3 already downloaded
# ../../data/raw/recordings/255544.mp3 already downloaded
# ../../data/raw/recordings/255544.mp3 already downloaded
# ../../data/raw/recordings/255544.flac already downloaded
# ../../data/raw/recordings/255497.mp3 already downloaded
# ../../data/raw/recordings/255497.mp3 already downloaded
# ../../data/raw/recordings/255513.mp3 already downloaded
# ../../data/raw/recordings/255513.mp3 already downloaded
# ../../data/raw/recordings/255513.mp3 already downloaded
# ../../data/raw/recordings/255518.mp3 already downloaded
# ../../data/raw/recordings/255518.mp3 already downloaded
# ../../data/raw/recordings/255518.mp3 already downloaded
# ../../data/raw/recordings/255518.mp3 already downloaded
# ../../data/raw/recordings/255526.mp3 already downloaded
# ../../data/raw/recordings/255623.mp3 already downloaded
# ../../data/raw/recordings/255623.mp3 already downloaded
# ../../data/raw/recordings/255623.mp3 already downloaded
# ../../data/raw/recordings/255623.mp3 already downloaded
# ../../data/raw/recordings/255623.mp3 already downloaded
# ../../data/raw/recordings/255623.mp3 already downloaded
# ../../data/raw/recordings/255623.mp3 already downloaded
# ../../data/raw/recordings/255623.mp3 already downloaded
# ../../data/raw/recordings/255624.mp3 already downloaded
# ../../data/raw/recordings/255624.mp3 already downloaded
# ../../data/raw/recordings/255624.mp3 already downloaded
# ../../data/raw/recordings/255624.mp3 already downloaded
# ../../data/raw/recordings/255624.mp3 already downloaded
# ../../data/raw/recordings/255624.mp3 already downloaded
# ../../data/raw/recordings/255624.mp3 already downloaded
# ../../data/raw/recordings/255624.mp3 already downloaded
# ../../data/raw/recordings/255624.mp3 already downloaded
# ../../data/raw/recordings/255624.mp3 already downloaded
# ../../data/raw/recordings/255624.mp3 already downloaded
# ../../data/raw/recordings/255624.mp3 already downloaded
# ../../data/raw/recordings/255624.mp3 already downloaded
# ../../data/raw/recordings/255624.mp3 already downloaded
# ../../data/raw/recordings/255624.mp3 already downloaded
# ../../data/raw/recordings/255624.mp3 already downloaded
# ../../data/raw/recordings/255624.mp3 already downloaded
# ../../data/raw/recordings/255624.mp3 already downloaded
# ../../data/raw/recordings/255624.mp3 already downloaded
# ../../data/raw/recordings/255624.mp3 already downloaded
# ../../data/raw/recordings/255624.mp3 already downloaded
# ../../data/raw/recordings/255624.flac already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.mp3 already downloaded
# ../../data/raw/recordings/255625.flac already downloaded
# ../../data/raw/recordings/255580.mp3 already downloaded
# ../../data/raw/recordings/255581.mp3 already downloaded
# ../../data/raw/recordings/255581.mp3 already downloaded
# ../../data/raw/recordings/255581.mp3 already downloaded
# ../../data/raw/recordings/255581.mp3 already downloaded
# ../../data/raw/recordings/255581.mp3 already downloaded
# ../../data/raw/recordings/255581.mp3 already downloaded
# ../../data/raw/recordings/255581.mp3 already downloaded
# ../../data/raw/recordings/255581.mp3 already downloaded
# ../../data/raw/recordings/255581.mp3 already downloaded
# ../../data/raw/recordings/255581.mp3 already downloaded
# ../../data/raw/recordings/255581.mp3 already downloaded
# ../../data/raw/recordings/255581.mp3 already downloaded
# ../../data/raw/recordings/255581.mp3 already downloaded
# ../../data/raw/recordings/255582.mp3 already downloaded
# ../../data/raw/recordings/255582.mp3 already downloaded
# ../../data/raw/recordings/255582.mp3 already downloaded
# ../../data/raw/recordings/255582.mp3 already downloaded
# ../../data/raw/recordings/255582.mp3 already downloaded
# ../../data/raw/recordings/255582.mp3 already downloaded
# ../../data/raw/recordings/255582.mp3 already downloaded
# ../../data/raw/recordings/255582.mp3 already downloaded
# ../../data/raw/recordings/255582.mp3 already downloaded
# ../../data/raw/recordings/255582.mp3 already downloaded
# ../../data/raw/recordings/255649.mp3 already downloaded
# ../../data/raw/recordings/255649.mp3 already downloaded
# ../../data/raw/recordings/255607.mp3 already downloaded
# ../../data/raw/recordings/255665.mp3 already downloaded
# ../../data/raw/recordings/255665.mp3 already downloaded
# ../../data/raw/recordings/255665.mp3 already downloaded
# ../../data/raw/recordings/255665.mp3 already downloaded
# ../../data/raw/recordings/255665.mp3 already downloaded
# ../../data/raw/recordings/256033.mp3 already downloaded
# ../../data/raw/recordings/256035.mp3 already downloaded
# ../../data/raw/recordings/256035.mp3 already downloaded
# ../../data/raw/recordings/256035.mp3 already downloaded
# ../../data/raw/recordings/256035.mp3 already downloaded
# ../../data/raw/recordings/256035.mp3 already downloaded
# ../../data/raw/recordings/256035.mp3 already downloaded
# ../../data/raw/recordings/256035.mp3 already downloaded
# ../../data/raw/recordings/256035.mp3 already downloaded
# ../../data/raw/recordings/256035.mp3 already downloaded
# ../../data/raw/recordings/256035.mp3 already downloaded
# ../../data/raw/recordings/256035.mp3 already downloaded
# ../../data/raw/recordings/256035.mp3 already downloaded
# ../../data/raw/recordings/256035.mp3 already downloaded
# ../../data/raw/recordings/256035.mp3 already downloaded
# ../../data/raw/recordings/256035.mp3 already downloaded
# ../../data/raw/recordings/256035.mp3 already downloaded
# ../../data/raw/recordings/256035.mp3 already downloaded
# ../../data/raw/recordings/256035.mp3 already downloaded
# ../../data/raw/recordings/256035.mp3 already downloaded
# ../../data/raw/recordings/256035.mp3 already downloaded
# ../../data/raw/recordings/256053.mp3 already downloaded
# ../../data/raw/recordings/256053.mp3 already downloaded
# ../../data/raw/recordings/256055.mp3 already downloaded
# ../../data/raw/recordings/256055.mp3 already downloaded
# ../../data/raw/recordings/256055.mp3 already downloaded
# ../../data/raw/recordings/256055.mp3 already downloaded
# ../../data/raw/recordings/256055.mp3 already downloaded
# ../../data/raw/recordings/256055.mp3 already downloaded
# ../../data/raw/recordings/256055.mp3 already downloaded
# ../../data/raw/recordings/256055.mp3 already downloaded
# ../../data/raw/recordings/256055.mp3 already downloaded
# ../../data/raw/recordings/256055.mp3 already downloaded
# ../../data/raw/recordings/256055.mp3 already downloaded
# ../../data/raw/recordings/256055.mp3 already downloaded
# ../../data/raw/recordings/256055.mp3 already downloaded
# ../../data/raw/recordings/256055.mp3 already downloaded
# ../../data/raw/recordings/256055.mp3 already downloaded
# ../../data/raw/recordings/156863.mp3 already downloaded
# ../../data/raw/recordings/156863.mp3 already downloaded
# ../../data/raw/recordings/156863.mp3 already downloaded
# ../../data/raw/recordings/156955.mp3 already downloaded
# ../../data/raw/recordings/156955.mp3 already downloaded
# ../../data/raw/recordings/156955.mp3 already downloaded
# ../../data/raw/recordings/69028.mp3 already downloaded
# ../../data/raw/recordings/74212.mp3 already downloaded
# ../../data/raw/recordings/74221.mp3 already downloaded
# ../../data/raw/recordings/74221.mp3 already downloaded
# ../../data/raw/recordings/74221.mp3 already downloaded
# ../../data/raw/recordings/74291.mp3 already downloaded
# ../../data/raw/recordings/74291.mp3 already downloaded
# ../../data/raw/recordings/74297.mp3 already downloaded
# ../../data/raw/recordings/74297.mp3 already downloaded
# ../../data/raw/recordings/74297.mp3 already downloaded
# ../../data/raw/recordings/74363.mp3 already downloaded
# ../../data/raw/recordings/74363.mp3 already downloaded
# ../../data/raw/recordings/92084.mp3 already downloaded
# ../../data/raw/recordings/74413.mp3 already downloaded
# ../../data/raw/recordings/163473.mp3 already downloaded
# ../../data/raw/recordings/163473.mp3 already downloaded
# ../../data/raw/recordings/163473.mp3 already downloaded
# ../../data/raw/recordings/163467.mp3 already downloaded
# ../../data/raw/recordings/163467.mp3 already downloaded
# ../../data/raw/recordings/163467.mp3 already downloaded
# ../../data/raw/recordings/163482.mp3 already downloaded
# ../../data/raw/recordings/163485.mp3 already downloaded
# ../../data/raw/recordings/163485.mp3 already downloaded
# ../../data/raw/recordings/163485.mp3 already downloaded
# ../../data/raw/recordings/157018.mp3 already downloaded
# ../../data/raw/recordings/157018.mp3 already downloaded
# ../../data/raw/recordings/156994.mp3 already downloaded
# ../../data/raw/recordings/156994.mp3 already downloaded
# ../../data/raw/recordings/75275.mp3 already downloaded
# ../../data/raw/recordings/75275.mp3 already downloaded
# ../../data/raw/recordings/75698.mp3 already downloaded
# ../../data/raw/recordings/99109.mp3 already downloaded
# ../../data/raw/recordings/99114.mp3 already downloaded
# ../../data/raw/recordings/99114.mp3 already downloaded
# ../../data/raw/recordings/99113.mp3 already downloaded
# ../../data/raw/recordings/99113.mp3 already downloaded
# ../../data/raw/recordings/99113.mp3 already downloaded
# ../../data/raw/recordings/99112.mp3 already downloaded
# ../../data/raw/recordings/99112.mp3 already downloaded
# ../../data/raw/recordings/99112.mp3 already downloaded
# ../../data/raw/recordings/99112.mp3 already downloaded
# ../../data/raw/recordings/44890.mp3 already downloaded
# ../../data/raw/recordings/44890.mp3 already downloaded
# ../../data/raw/recordings/44894.mp3 already downloaded
# ../../data/raw/recordings/44894.mp3 already downloaded
# ../../data/raw/recordings/44894.mp3 already downloaded
# ../../data/raw/recordings/44891.mp3 already downloaded
# ../../data/raw/recordings/44891.mp3 already downloaded
# ../../data/raw/recordings/44891.mp3 already downloaded
# ../../data/raw/recordings/44892.mp3 already downloaded
# ../../data/raw/recordings/44892.mp3 already downloaded
# ../../data/raw/recordings/44892.mp3 already downloaded
# ../../data/raw/recordings/44892.mp3 already downloaded
# ../../data/raw/recordings/44892.mp3 already downloaded
# ../../data/raw/recordings/44898.mp3 already downloaded
# ../../data/raw/recordings/44898.mp3 already downloaded
# ../../data/raw/recordings/44896.mp3 already downloaded
# ../../data/raw/recordings/44896.mp3 already downloaded
# ../../data/raw/recordings/44896.mp3 already downloaded
# ../../data/raw/recordings/44896.mp3 already downloaded
# ../../data/raw/recordings/44896.mp3 already downloaded
# ../../data/raw/recordings/44897.mp3 already downloaded
# ../../data/raw/recordings/44897.mp3 already downloaded
# ../../data/raw/recordings/44897.mp3 already downloaded
# ../../data/raw/recordings/44899.mp3 already downloaded
# ../../data/raw/recordings/44899.mp3 already downloaded
# ../../data/raw/recordings/44899.mp3 already downloaded
# ../../data/raw/recordings/44899.mp3 already downloaded
# ../../data/raw/recordings/44899.mp3 already downloaded
# ../../data/raw/recordings/44905.mp3 already downloaded
# ../../data/raw/recordings/44905.mp3 already downloaded
# ../../data/raw/recordings/44946.mp3 already downloaded
# ../../data/raw/recordings/44946.mp3 already downloaded
# ../../data/raw/recordings/44945.mp3 already downloaded
# ../../data/raw/recordings/44945.mp3 already downloaded
# ../../data/raw/recordings/44945.mp3 already downloaded
# ../../data/raw/recordings/44943.mp3 already downloaded
# ../../data/raw/recordings/44943.mp3 already downloaded
# ../../data/raw/recordings/44949.mp3 already downloaded
# ../../data/raw/recordings/44949.mp3 already downloaded
# ../../data/raw/recordings/44815.mp3 already downloaded
# ../../data/raw/recordings/44815.mp3 already downloaded
# ../../data/raw/recordings/44815.mp3 already downloaded
# ../../data/raw/recordings/99092.mp3 already downloaded
# ../../data/raw/recordings/99092.mp3 already downloaded
# ../../data/raw/recordings/99092.mp3 already downloaded
# ../../data/raw/recordings/99097.mp3 already downloaded
# ../../data/raw/recordings/99098.mp3 already downloaded
# ../../data/raw/recordings/99098.mp3 already downloaded
# ../../data/raw/recordings/99098.mp3 already downloaded
# ../../data/raw/recordings/99098.mp3 already downloaded
# ../../data/raw/recordings/99098.mp3 already downloaded
# ../../data/raw/recordings/99098.mp3 already downloaded
# ../../data/raw/recordings/99100.mp3 already downloaded
# ../../data/raw/recordings/99100.mp3 already downloaded
# ../../data/raw/recordings/6714.mp3 already downloaded
# ../../data/raw/recordings/6853.mp3 already downloaded
# ../../data/raw/recordings/6853.mp3 already downloaded
# ../../data/raw/recordings/6853.mp3 already downloaded
# ../../data/raw/recordings/6852.mp3 already downloaded
# ../../data/raw/recordings/6852.mp3 already downloaded
# ../../data/raw/recordings/6851.mp3 already downloaded
# ../../data/raw/recordings/6851.mp3 already downloaded
# ../../data/raw/recordings/7311.mp3 already downloaded
# ../../data/raw/recordings/7309.mp3 already downloaded
# ../../data/raw/recordings/69256.mp3 already downloaded
# ../../data/raw/recordings/69256.mp3 already downloaded
# ../../data/raw/recordings/69256.mp3 already downloaded
# ../../data/raw/recordings/69894.mp3 already downloaded
# ../../data/raw/recordings/69894.mp3 already downloaded
# ../../data/raw/recordings/104149.mp3 already downloaded
# ../../data/raw/recordings/104149.mp3 already downloaded
# ../../data/raw/recordings/104149.mp3 already downloaded
# ../../data/raw/recordings/70890.mp3 already downloaded
# ../../data/raw/recordings/70937.mp3 already downloaded
# ../../data/raw/recordings/70937.mp3 already downloaded
# ../../data/raw/recordings/70937.mp3 already downloaded
# ../../data/raw/recordings/70958.mp3 already downloaded
# ../../data/raw/recordings/70958.mp3 already downloaded
# ../../data/raw/recordings/70985.mp3 already downloaded
# ../../data/raw/recordings/70985.mp3 already downloaded
# ../../data/raw/recordings/157003.mp3 already downloaded
# ../../data/raw/recordings/157003.mp3 already downloaded
# ../../data/raw/recordings/157003.mp3 already downloaded
# ../../data/raw/recordings/156401.mp3 already downloaded
# ../../data/raw/recordings/156401.mp3 already downloaded
# ../../data/raw/recordings/357824.flac already downloaded
# ../../data/raw/recordings/331651.mp3 already downloaded
# ../../data/raw/recordings/331696.mp3 already downloaded
# ../../data/raw/recordings/331709.mp3 already downloaded
# ../../data/raw/recordings/331717.mp3 already downloaded
# ../../data/raw/recordings/339619.mp3 already downloaded
# ../../data/raw/recordings/339597.mp3 already downloaded
# ../../data/raw/recordings/321431.mp3 already downloaded
# ../../data/raw/recordings/321436.mp3 already downloaded
# ../../data/raw/recordings/321436.mp3 already downloaded
# ../../data/raw/recordings/321437.mp3 already downloaded
# ../../data/raw/recordings/322587.mp3 already downloaded
# ../../data/raw/recordings/322584.mp3 already downloaded
# ../../data/raw/recordings/389388.flac already downloaded
# ../../data/raw/recordings/389674.flac already downloaded
# ../../data/raw/recordings/389640.flac already downloaded
# ../../data/raw/recordings/391227.flac already downloaded
# ../../data/raw/recordings/389642.flac already downloaded
# ../../data/raw/recordings/391221.flac already downloaded
# ../../data/raw/recordings/389628.flac already downloaded
# ../../data/raw/recordings/389683.flac already downloaded
# ../../data/raw/recordings/391230.flac already downloaded
# ../../data/raw/recordings/391214.flac already downloaded
# ../../data/raw/recordings/389684.flac already downloaded
# ../../data/raw/recordings/391388.flac already downloaded
# ../../data/raw/recordings/389635.flac already downloaded
# ../../data/raw/recordings/391236.flac already downloaded
# ../../data/raw/recordings/389450.flac already downloaded
# ../../data/raw/recordings/390114.flac already downloaded
# ../../data/raw/recordings/390113.flac already downloaded
# ../../data/raw/recordings/389402.flac already downloaded
# ../../data/raw/recordings/389188.flac already downloaded
# ../../data/raw/recordings/389007.flac already downloaded
# ../../data/raw/recordings/391050.flac already downloaded
# ../../data/raw/recordings/391372.flac already downloaded
# ../../data/raw/recordings/391374.flac already downloaded
# ../../data/raw/recordings/391352.flac already downloaded
# ../../data/raw/recordings/389423.flac already downloaded
# ../../data/raw/recordings/322740.mp3 already downloaded
# ../../data/raw/recordings/330504.mp3 already downloaded
# ../../data/raw/recordings/330520.mp3 already downloaded
# ../../data/raw/recordings/330512.mp3 already downloaded
# ../../data/raw/recordings/330512.mp3 already downloaded
# ../../data/raw/recordings/330517.mp3 already downloaded
# ../../data/raw/recordings/330530.mp3 already downloaded
# ../../data/raw/recordings/330554.mp3 already downloaded
# ../../data/raw/recordings/321055.mp3 already downloaded
# ../../data/raw/recordings/321063.mp3 already downloaded
# ../../data/raw/recordings/321080.mp3 already downloaded
# ../../data/raw/recordings/321073.mp3 already downloaded
# ../../data/raw/recordings/331093.mp3 already downloaded
# ../../data/raw/recordings/331044.mp3 already downloaded
# ../../data/raw/recordings/331374.mp3 already downloaded
# ../../data/raw/recordings/331398.mp3 already downloaded
# ../../data/raw/recordings/331353.mp3 already downloaded
# ../../data/raw/recordings/331436.mp3 already downloaded
# ../../data/raw/recordings/331454.mp3 already downloaded
# ../../data/raw/recordings/66890.mp3 already downloaded
# ../../data/raw/recordings/43757.mp3 already downloaded
# ../../data/raw/recordings/43757.mp3 already downloaded
# ../../data/raw/recordings/43757.mp3 already downloaded
# ../../data/raw/recordings/43761.mp3 already downloaded
# ../../data/raw/recordings/43761.mp3 already downloaded
# ../../data/raw/recordings/43761.mp3 already downloaded
# ../../data/raw/recordings/43764.mp3 already downloaded
# ../../data/raw/recordings/43764.mp3 already downloaded
# ../../data/raw/recordings/103697.mp3 already downloaded
# ../../data/raw/recordings/103697.mp3 already downloaded
# ../../data/raw/recordings/103697.mp3 already downloaded
# ../../data/raw/recordings/4315.mp3 already downloaded
# ../../data/raw/recordings/4315.mp3 already downloaded
# ../../data/raw/recordings/4315.mp3 already downloaded
# ../../data/raw/recordings/4396.mp3 already downloaded
# ../../data/raw/recordings/4396.mp3 already downloaded
# ../../data/raw/recordings/4427.mp3 already downloaded
# ../../data/raw/recordings/4427.mp3 already downloaded
# ../../data/raw/recordings/4429.mp3 already downloaded
# ../../data/raw/recordings/4429.mp3 already downloaded
# ../../data/raw/recordings/4429.mp3 already downloaded
# ../../data/raw/recordings/103753.mp3 already downloaded
# ../../data/raw/recordings/103753.mp3 already downloaded
# ../../data/raw/recordings/4452.mp3 already downloaded
# ../../data/raw/recordings/4452.mp3 already downloaded
# ../../data/raw/recordings/4446.mp3 already downloaded
# ../../data/raw/recordings/4446.mp3 already downloaded
# ../../data/raw/recordings/4446.mp3 already downloaded
# ../../data/raw/recordings/103760.mp3 already downloaded
# ../../data/raw/recordings/103760.mp3 already downloaded
# ../../data/raw/recordings/103760.mp3 already downloaded
# ../../data/raw/recordings/103758.mp3 already downloaded
# ../../data/raw/recordings/103758.mp3 already downloaded
# ../../data/raw/recordings/4454.mp3 already downloaded
# ../../data/raw/recordings/4454.mp3 already downloaded
# ../../data/raw/recordings/4454.mp3 already downloaded
# ../../data/raw/recordings/4454.mp3 already downloaded
# ../../data/raw/recordings/4454.mp3 already downloaded
# ../../data/raw/recordings/103763.mp3 already downloaded
# ../../data/raw/recordings/103763.mp3 already downloaded
# ../../data/raw/recordings/103763.mp3 already downloaded
# ../../data/raw/recordings/103764.mp3 already downloaded
# ../../data/raw/recordings/103764.mp3 already downloaded
# ../../data/raw/recordings/4465.mp3 already downloaded
# ../../data/raw/recordings/4465.mp3 already downloaded
# ../../data/raw/recordings/4465.mp3 already downloaded
# ../../data/raw/recordings/103765.mp3 already downloaded
# ../../data/raw/recordings/103770.mp3 already downloaded
# ../../data/raw/recordings/103772.mp3 already downloaded
# ../../data/raw/recordings/4478.mp3 already downloaded
# ../../data/raw/recordings/4478.mp3 already downloaded
# ../../data/raw/recordings/4478.mp3 already downloaded
# ../../data/raw/recordings/103776.mp3 already downloaded
# ../../data/raw/recordings/103776.mp3 already downloaded
# ../../data/raw/recordings/103776.mp3 already downloaded
# ../../data/raw/recordings/4484.mp3 already downloaded
# ../../data/raw/recordings/4484.mp3 already downloaded
# ../../data/raw/recordings/4482.mp3 already downloaded
# ../../data/raw/recordings/4482.mp3 already downloaded
# ../../data/raw/recordings/4482.mp3 already downloaded
# ../../data/raw/recordings/4480.mp3 already downloaded
# ../../data/raw/recordings/103779.mp3 already downloaded
# ../../data/raw/recordings/103779.mp3 already downloaded
# ../../data/raw/recordings/103779.mp3 already downloaded
# ../../data/raw/recordings/4490.mp3 already downloaded
# ../../data/raw/recordings/4490.mp3 already downloaded
# ../../data/raw/recordings/4490.mp3 already downloaded
# ../../data/raw/recordings/103783.mp3 already downloaded
# ../../data/raw/recordings/103783.mp3 already downloaded
# ../../data/raw/recordings/103783.mp3 already downloaded
# ../../data/raw/recordings/103783.mp3 already downloaded
# ../../data/raw/recordings/103783.mp3 already downloaded
# ../../data/raw/recordings/103782.mp3 already downloaded
# ../../data/raw/recordings/103781.mp3 already downloaded
# ../../data/raw/recordings/103781.mp3 already downloaded
# ../../data/raw/recordings/103781.mp3 already downloaded
# ../../data/raw/recordings/4503.mp3 already downloaded
# ../../data/raw/recordings/4503.mp3 already downloaded
# ../../data/raw/recordings/4503.mp3 already downloaded
# ../../data/raw/recordings/4505.mp3 already downloaded
# ../../data/raw/recordings/4505.mp3 already downloaded
# ../../data/raw/recordings/4505.mp3 already downloaded
# ../../data/raw/recordings/4539.mp3 already downloaded
# ../../data/raw/recordings/4547.mp3 already downloaded
# ../../data/raw/recordings/4547.mp3 already downloaded
# ../../data/raw/recordings/103813.mp3 already downloaded
# ../../data/raw/recordings/103813.mp3 already downloaded
# ../../data/raw/recordings/103813.mp3 already downloaded
# ../../data/raw/recordings/103815.mp3 already downloaded
# ../../data/raw/recordings/103815.mp3 already downloaded
# ../../data/raw/recordings/103815.mp3 already downloaded
# ../../data/raw/recordings/103816.mp3 already downloaded
# ../../data/raw/recordings/103816.mp3 already downloaded
# ../../data/raw/recordings/103816.mp3 already downloaded
# ../../data/raw/recordings/103816.mp3 already downloaded
# ../../data/raw/recordings/103816.mp3 already downloaded
# ../../data/raw/recordings/4561.mp3 already downloaded
# ../../data/raw/recordings/4571.mp3 already downloaded
# ../../data/raw/recordings/4578.mp3 already downloaded
# ../../data/raw/recordings/4576.mp3 already downloaded
# ../../data/raw/recordings/4576.mp3 already downloaded
# ../../data/raw/recordings/4592.mp3 already downloaded
# ../../data/raw/recordings/4592.mp3 already downloaded
# ../../data/raw/recordings/103832.mp3 already downloaded
# ../../data/raw/recordings/4601.mp3 already downloaded
# ../../data/raw/recordings/4601.mp3 already downloaded
# ../../data/raw/recordings/4601.mp3 already downloaded
# ../../data/raw/recordings/4596.mp3 already downloaded
# ../../data/raw/recordings/103836.mp3 already downloaded
# ../../data/raw/recordings/103836.mp3 already downloaded
# ../../data/raw/recordings/103836.mp3 already downloaded
# ../../data/raw/recordings/4605.mp3 already downloaded
# ../../data/raw/recordings/4607.mp3 already downloaded
# ../../data/raw/recordings/4607.mp3 already downloaded
# ../../data/raw/recordings/4611.mp3 already downloaded
# ../../data/raw/recordings/4611.mp3 already downloaded
# ../../data/raw/recordings/4611.mp3 already downloaded
# ../../data/raw/recordings/4615.mp3 already downloaded
# ../../data/raw/recordings/4615.mp3 already downloaded
# ../../data/raw/recordings/4615.mp3 already downloaded
# ../../data/raw/recordings/4684.mp3 already downloaded
# ../../data/raw/recordings/4684.mp3 already downloaded
# ../../data/raw/recordings/4684.mp3 already downloaded
# ../../data/raw/recordings/4688.mp3 already downloaded
# ../../data/raw/recordings/4688.mp3 already downloaded
# ../../data/raw/recordings/4690.mp3 already downloaded
# ../../data/raw/recordings/4690.mp3 already downloaded
# ../../data/raw/recordings/4690.mp3 already downloaded
# ../../data/raw/recordings/4739.mp3 already downloaded
# ../../data/raw/recordings/48526.mp3 already downloaded
# ../../data/raw/recordings/48526.mp3 already downloaded
# ../../data/raw/recordings/48526.mp3 already downloaded
# ../../data/raw/recordings/48525.mp3 already downloaded
# ../../data/raw/recordings/48525.mp3 already downloaded
# ../../data/raw/recordings/48525.mp3 already downloaded
# ../../data/raw/recordings/48524.mp3 already downloaded
# ../../data/raw/recordings/48524.mp3 already downloaded
# ../../data/raw/recordings/48524.mp3 already downloaded
# ../../data/raw/recordings/48527.mp3 already downloaded
# ../../data/raw/recordings/48532.mp3 already downloaded
# ../../data/raw/recordings/48532.mp3 already downloaded
# ../../data/raw/recordings/48532.mp3 already downloaded
# ../../data/raw/recordings/48537.mp3 already downloaded
# ../../data/raw/recordings/48537.mp3 already downloaded
# ../../data/raw/recordings/48538.mp3 already downloaded
# ../../data/raw/recordings/48538.mp3 already downloaded
# ../../data/raw/recordings/48538.mp3 already downloaded
# ../../data/raw/recordings/48536.mp3 already downloaded
# ../../data/raw/recordings/48536.mp3 already downloaded
# ../../data/raw/recordings/48542.mp3 already downloaded
# ../../data/raw/recordings/48542.mp3 already downloaded
# ../../data/raw/recordings/48542.mp3 already downloaded
# ../../data/raw/recordings/48543.mp3 already downloaded
# ../../data/raw/recordings/48543.mp3 already downloaded
# ../../data/raw/recordings/48543.mp3 already downloaded
# ../../data/raw/recordings/48541.mp3 already downloaded
# ../../data/raw/recordings/48541.mp3 already downloaded
# ../../data/raw/recordings/48541.mp3 already downloaded
# ../../data/raw/recordings/4787.mp3 already downloaded
# ../../data/raw/recordings/4787.mp3 already downloaded
# ../../data/raw/recordings/4787.mp3 already downloaded
# ../../data/raw/recordings/103879.mp3 already downloaded
# ../../data/raw/recordings/4805.mp3 already downloaded
# ../../data/raw/recordings/4805.mp3 already downloaded
# ../../data/raw/recordings/4805.mp3 already downloaded
# ../../data/raw/recordings/4812.mp3 already downloaded
# ../../data/raw/recordings/4812.mp3 already downloaded
# ../../data/raw/recordings/4812.mp3 already downloaded
# ../../data/raw/recordings/4807.mp3 already downloaded
# ../../data/raw/recordings/4807.mp3 already downloaded
# ../../data/raw/recordings/4819.mp3 already downloaded
# ../../data/raw/recordings/4817.mp3 already downloaded
# ../../data/raw/recordings/4817.mp3 already downloaded
# ../../data/raw/recordings/4830.mp3 already downloaded
# ../../data/raw/recordings/4825.mp3 already downloaded
# ../../data/raw/recordings/4825.mp3 already downloaded
# ../../data/raw/recordings/103883.mp3 already downloaded
# ../../data/raw/recordings/103883.mp3 already downloaded
# ../../data/raw/recordings/103882.mp3 already downloaded
# ../../data/raw/recordings/103884.mp3 already downloaded
# ../../data/raw/recordings/286234.mp3 already downloaded
# ../../data/raw/recordings/286234.mp3 already downloaded
# ../../data/raw/recordings/286245.mp3 already downloaded
# ../../data/raw/recordings/286215.mp3 already downloaded
# ../../data/raw/recordings/286215.mp3 already downloaded
# ../../data/raw/recordings/286215.mp3 already downloaded
# ../../data/raw/recordings/4839.mp3 already downloaded
# ../../data/raw/recordings/4839.mp3 already downloaded
# ../../data/raw/recordings/4839.mp3 already downloaded
# ../../data/raw/recordings/4837.mp3 already downloaded
# ../../data/raw/recordings/4837.mp3 already downloaded
# ../../data/raw/recordings/4455.mp3 already downloaded
# ../../data/raw/recordings/83527.mp3 already downloaded
# ../../data/raw/recordings/50009.mp3 already downloaded
# ../../data/raw/recordings/50010.mp3 already downloaded
# ../../data/raw/recordings/50010.mp3 already downloaded
# ../../data/raw/recordings/100120.mp3 already downloaded
# ../../data/raw/recordings/100120.mp3 already downloaded
# ../../data/raw/recordings/100120.mp3 already downloaded
# ../../data/raw/recordings/286237.mp3 already downloaded
# ../../data/raw/recordings/50017.mp3 already downloaded
# ../../data/raw/recordings/50017.mp3 already downloaded
# ../../data/raw/recordings/50016.mp3 already downloaded
# ../../data/raw/recordings/50016.mp3 already downloaded
# ../../data/raw/recordings/50016.mp3 already downloaded
# ../../data/raw/recordings/100121.mp3 already downloaded
# ../../data/raw/recordings/100121.mp3 already downloaded
# ../../data/raw/recordings/100121.mp3 already downloaded
# ../../data/raw/recordings/50021.mp3 already downloaded
# ../../data/raw/recordings/50021.mp3 already downloaded
# ../../data/raw/recordings/50021.mp3 already downloaded
# ../../data/raw/recordings/50022.mp3 already downloaded
# ../../data/raw/recordings/50022.mp3 already downloaded
# ../../data/raw/recordings/50022.mp3 already downloaded
# ../../data/raw/recordings/100128.mp3 already downloaded
# ../../data/raw/recordings/100128.mp3 already downloaded
# ../../data/raw/recordings/100128.mp3 already downloaded
# ../../data/raw/recordings/100125.mp3 already downloaded
# ../../data/raw/recordings/100125.mp3 already downloaded
# ../../data/raw/recordings/100125.mp3 already downloaded
# ../../data/raw/recordings/83565.mp3 already downloaded
# ../../data/raw/recordings/83565.mp3 already downloaded
# ../../data/raw/recordings/83565.mp3 already downloaded
# ../../data/raw/recordings/50028.mp3 already downloaded
# ../../data/raw/recordings/50028.mp3 already downloaded
# ../../data/raw/recordings/50028.mp3 already downloaded
# ../../data/raw/recordings/100130.mp3 already downloaded
# ../../data/raw/recordings/100130.mp3 already downloaded
# ../../data/raw/recordings/100130.mp3 already downloaded
# ../../data/raw/recordings/100132.mp3 already downloaded
# ../../data/raw/recordings/100131.mp3 already downloaded
# ../../data/raw/recordings/100131.mp3 already downloaded
# ../../data/raw/recordings/100131.mp3 already downloaded
# ../../data/raw/recordings/100129.mp3 already downloaded
# ../../data/raw/recordings/100129.mp3 already downloaded
# ../../data/raw/recordings/100129.mp3 already downloaded
# ../../data/raw/recordings/50033.mp3 already downloaded
# ../../data/raw/recordings/50033.mp3 already downloaded
# ../../data/raw/recordings/50032.mp3 already downloaded
# ../../data/raw/recordings/50032.mp3 already downloaded
# ../../data/raw/recordings/50032.mp3 already downloaded
# ../../data/raw/recordings/100136.mp3 already downloaded
# ../../data/raw/recordings/100136.mp3 already downloaded
# ../../data/raw/recordings/100136.mp3 already downloaded
# ../../data/raw/recordings/100136.mp3 already downloaded
# ../../data/raw/recordings/100136.mp3 already downloaded
# ../../data/raw/recordings/100136.mp3 already downloaded
# ../../data/raw/recordings/100133.mp3 already downloaded
# ../../data/raw/recordings/50038.mp3 already downloaded
# ../../data/raw/recordings/100139.mp3 already downloaded
# ../../data/raw/recordings/100138.mp3 already downloaded
# ../../data/raw/recordings/100138.mp3 already downloaded
# ../../data/raw/recordings/100138.mp3 already downloaded
# ../../data/raw/recordings/100140.mp3 already downloaded
# ../../data/raw/recordings/100140.mp3 already downloaded
# ../../data/raw/recordings/100140.mp3 already downloaded
# ../../data/raw/recordings/100137.mp3 already downloaded
# ../../data/raw/recordings/100137.mp3 already downloaded
# ../../data/raw/recordings/100137.mp3 already downloaded
# ../../data/raw/recordings/50045.mp3 already downloaded
# ../../data/raw/recordings/50045.mp3 already downloaded
# ../../data/raw/recordings/50045.mp3 already downloaded
# ../../data/raw/recordings/50044.mp3 already downloaded
# ../../data/raw/recordings/50044.mp3 already downloaded
# ../../data/raw/recordings/50044.mp3 already downloaded
# ../../data/raw/recordings/50042.mp3 already downloaded
# ../../data/raw/recordings/50042.mp3 already downloaded
# ../../data/raw/recordings/50042.mp3 already downloaded
# ../../data/raw/recordings/50046.mp3 already downloaded
# ../../data/raw/recordings/50046.mp3 already downloaded
# ../../data/raw/recordings/100144.mp3 already downloaded
# ../../data/raw/recordings/100144.mp3 already downloaded
# ../../data/raw/recordings/100144.mp3 already downloaded
# ../../data/raw/recordings/100141.mp3 already downloaded
# ../../data/raw/recordings/100141.mp3 already downloaded
# ../../data/raw/recordings/100141.mp3 already downloaded
# ../../data/raw/recordings/100142.mp3 already downloaded
# ../../data/raw/recordings/100142.mp3 already downloaded
# ../../data/raw/recordings/100142.mp3 already downloaded
# ../../data/raw/recordings/286216.mp3 already downloaded
# ../../data/raw/recordings/50049.mp3 already downloaded
# ../../data/raw/recordings/50049.mp3 already downloaded
# ../../data/raw/recordings/50049.mp3 already downloaded
# ../../data/raw/recordings/50047.mp3 already downloaded
# ../../data/raw/recordings/50047.mp3 already downloaded
# ../../data/raw/recordings/50047.mp3 already downloaded
# ../../data/raw/recordings/100148.mp3 already downloaded
# ../../data/raw/recordings/100148.mp3 already downloaded
# ../../data/raw/recordings/100148.mp3 already downloaded
# ../../data/raw/recordings/100148.mp3 already downloaded
# ../../data/raw/recordings/100148.mp3 already downloaded
# ../../data/raw/recordings/100148.mp3 already downloaded
# ../../data/raw/recordings/100148.mp3 already downloaded
# ../../data/raw/recordings/100148.mp3 already downloaded
# ../../data/raw/recordings/100147.mp3 already downloaded
# ../../data/raw/recordings/100147.mp3 already downloaded
# ../../data/raw/recordings/100152.mp3 already downloaded
# ../../data/raw/recordings/100152.mp3 already downloaded
# ../../data/raw/recordings/83610.mp3 already downloaded
# ../../data/raw/recordings/83610.mp3 already downloaded
# ../../data/raw/recordings/4488.mp3 already downloaded
# ../../data/raw/recordings/4488.mp3 already downloaded
# ../../data/raw/recordings/4488.mp3 already downloaded
# ../../data/raw/recordings/4486.mp3 already downloaded
# ../../data/raw/recordings/4486.mp3 already downloaded
# ../../data/raw/recordings/100160.mp3 already downloaded
# ../../data/raw/recordings/100160.mp3 already downloaded
# ../../data/raw/recordings/100160.mp3 already downloaded
# ../../data/raw/recordings/100158.mp3 already downloaded
# ../../data/raw/recordings/4504.mp3 already downloaded
# ../../data/raw/recordings/100168.mp3 already downloaded
# ../../data/raw/recordings/100168.mp3 already downloaded
# ../../data/raw/recordings/83640.mp3 already downloaded
# ../../data/raw/recordings/100169.mp3 already downloaded
# ../../data/raw/recordings/100169.mp3 already downloaded
# ../../data/raw/recordings/100169.mp3 already downloaded
# ../../data/raw/recordings/4534.mp3 already downloaded
# ../../data/raw/recordings/100175.mp3 already downloaded
# ../../data/raw/recordings/100175.mp3 already downloaded
# ../../data/raw/recordings/100175.mp3 already downloaded
# ../../data/raw/recordings/100175.mp3 already downloaded
# ../../data/raw/recordings/100175.mp3 already downloaded
# ../../data/raw/recordings/100175.mp3 already downloaded
# ../../data/raw/recordings/100173.mp3 already downloaded
# ../../data/raw/recordings/4554.mp3 already downloaded
# ../../data/raw/recordings/4554.mp3 already downloaded
# ../../data/raw/recordings/4548.mp3 already downloaded
# ../../data/raw/recordings/100180.mp3 already downloaded
# ../../data/raw/recordings/100180.mp3 already downloaded
# ../../data/raw/recordings/100180.mp3 already downloaded
# ../../data/raw/recordings/100178.mp3 already downloaded
# ../../data/raw/recordings/100178.mp3 already downloaded
# ../../data/raw/recordings/100178.mp3 already downloaded
# ../../data/raw/recordings/100179.mp3 already downloaded
# ../../data/raw/recordings/100179.mp3 already downloaded
# ../../data/raw/recordings/100179.mp3 already downloaded
# ../../data/raw/recordings/4563.mp3 already downloaded
# ../../data/raw/recordings/4563.mp3 already downloaded
# ../../data/raw/recordings/4563.mp3 already downloaded
# ../../data/raw/recordings/4566.mp3 already downloaded
# ../../data/raw/recordings/4566.mp3 already downloaded
# ../../data/raw/recordings/4560.mp3 already downloaded
# ../../data/raw/recordings/4560.mp3 already downloaded
# ../../data/raw/recordings/4557.mp3 already downloaded
# ../../data/raw/recordings/4557.mp3 already downloaded
# ../../data/raw/recordings/100182.mp3 already downloaded
# ../../data/raw/recordings/100182.mp3 already downloaded
# ../../data/raw/recordings/100182.mp3 already downloaded
# ../../data/raw/recordings/100182.mp3 already downloaded
# ...
# ../../data/raw/recordings/529944.flac already downloaded
# ../../data/raw/recordings/529944.flac already downloaded
# ../../data/raw/recordings/529645.flac already downloaded
# ../../data/raw/recordings/529645.flac already downloaded
# ../../data/raw/recordings/529645.flac already downloaded
# ../../data/raw/recordings/529737.flac already downloaded
# ../../data/raw/recordings/529723.flac already downloaded
# ../../data/raw/recordings/529752.flac already downloaded
# ../../data/raw/recordings/529895.flac already downloaded
# ../../data/raw/recordings/529966.flac already downloaded
# ../../data/raw/recordings/529923.flac already downloaded
# ../../data/raw/recordings/529629.flac already downloaded
# ../../data/raw/recordings/529843.flac already downloaded
# ../../data/raw/recordings/90031.mp3 already downloaded
# ../../data/raw/recordings/90031.mp3 already downloaded
# ../../data/raw/recordings/90031.mp3 already downloaded
# ../../data/raw/recordings/90196.mp3 already downloaded
# ../../data/raw/recordings/90196.mp3 already downloaded
# ../../data/raw/recordings/90808.mp3 already downloaded
# ../../data/raw/recordings/90808.mp3 already downloaded
# ../../data/raw/recordings/90831.mp3 already downloaded
# ../../data/raw/recordings/90421.mp3 already downloaded
# ../../data/raw/recordings/90421.mp3 already downloaded
# ../../data/raw/recordings/90421.mp3 already downloaded
# ../../data/raw/recordings/90430.mp3 already downloaded
# ../../data/raw/recordings/90430.mp3 already downloaded
# ../../data/raw/recordings/90430.mp3 already downloaded
# ../../data/raw/recordings/90721.mp3 already downloaded
# ../../data/raw/recordings/90721.mp3 already downloaded
# ../../data/raw/recordings/90721.mp3 already downloaded
# ../../data/raw/recordings/90434.mp3 already downloaded
# ../../data/raw/recordings/90434.mp3 already downloaded
# ../../data/raw/recordings/90434.mp3 already downloaded
# ../../data/raw/recordings/90478.mp3 already downloaded
# ../../data/raw/recordings/90443.mp3 already downloaded
# ../../data/raw/recordings/90443.mp3 already downloaded
# ../../data/raw/recordings/90443.mp3 already downloaded
# ../../data/raw/recordings/90452.mp3 already downloaded
# ../../data/raw/recordings/90452.mp3 already downloaded
# ../../data/raw/recordings/90456.mp3 already downloaded
# ../../data/raw/recordings/90456.mp3 already downloaded
# ../../data/raw/recordings/90456.mp3 already downloaded
# ../../data/raw/recordings/90460.mp3 already downloaded
# ../../data/raw/recordings/90460.mp3 already downloaded
# ../../data/raw/recordings/90460.mp3 already downloaded
# ../../data/raw/recordings/90465.mp3 already downloaded
# ../../data/raw/recordings/90465.mp3 already downloaded
# ../../data/raw/recordings/90812.mp3 already downloaded
# ../../data/raw/recordings/90812.mp3 already downloaded
# ../../data/raw/recordings/90816.mp3 already downloaded
# ../../data/raw/recordings/90599.mp3 already downloaded
# ../../data/raw/recordings/90599.mp3 already downloaded
# ../../data/raw/recordings/90599.mp3 already downloaded
# ../../data/raw/recordings/90591.mp3 already downloaded
# ../../data/raw/recordings/90591.mp3 already downloaded
# ../../data/raw/recordings/90591.mp3 already downloaded
# ../../data/raw/recordings/90595.mp3 already downloaded
# ../../data/raw/recordings/90595.mp3 already downloaded
# ../../data/raw/recordings/90595.mp3 already downloaded
# ../../data/raw/recordings/205221.mp3 already downloaded
# ../../data/raw/recordings/207234.mp3 already downloaded
# ../../data/raw/recordings/207114.mp3 already downloaded
# ../../data/raw/recordings/207443.mp3 already downloaded
# ../../data/raw/recordings/207437.mp3 already downloaded
# ../../data/raw/recordings/207225.mp3 already downloaded
# ../../data/raw/recordings/207550.mp3 already downloaded
# ../../data/raw/recordings/482026.flac already downloaded
# ../../data/raw/recordings/482006.flac already downloaded
# ../../data/raw/recordings/482012.flac already downloaded
# ../../data/raw/recordings/482013.flac already downloaded
# ../../data/raw/recordings/483110.flac already downloaded
# ../../data/raw/recordings/482099.flac already downloaded
# ../../data/raw/recordings/482104.flac already downloaded
# ../../data/raw/recordings/482100.flac already downloaded
# ../../data/raw/recordings/481376.flac already downloaded
# ../../data/raw/recordings/479486.flac already downloaded
# ../../data/raw/recordings/357693.mp3 already downloaded
# ../../data/raw/recordings/478708.flac already downloaded
# ../../data/raw/recordings/481735.flac already downloaded
# ../../data/raw/recordings/481585.flac already downloaded
# ../../data/raw/recordings/481734.flac already downloaded
# ../../data/raw/recordings/481762.flac already downloaded
# ../../data/raw/recordings/481882.flac already downloaded
# ../../data/raw/recordings/481837.flac already downloaded
# ../../data/raw/recordings/481678.flac already downloaded
# ../../data/raw/recordings/479470.flac already downloaded
# ../../data/raw/recordings/481662.flac already downloaded
# ../../data/raw/recordings/479476.flac already downloaded
# ../../data/raw/recordings/481861.flac already downloaded
# ../../data/raw/recordings/481847.flac already downloaded
# ../../data/raw/recordings/481842.flac already downloaded
# ../../data/raw/recordings/482320.flac already downloaded
# ../../data/raw/recordings/482339.flac already downloaded
# ../../data/raw/recordings/482321.flac already downloaded
# ../../data/raw/recordings/482372.flac already downloaded
# ../../data/raw/recordings/481327.flac already downloaded
# ../../data/raw/recordings/305332.mp3 already downloaded
# ../../data/raw/recordings/216223.mp3 already downloaded
# ../../data/raw/recordings/216297.mp3 already downloaded
# ../../data/raw/recordings/216199.mp3 already downloaded
# ../../data/raw/recordings/521429.flac already downloaded
# ../../data/raw/recordings/521406.flac already downloaded
# ../../data/raw/recordings/521503.flac already downloaded
# ../../data/raw/recordings/521417.flac already downloaded
# ../../data/raw/recordings/521457.flac already downloaded
# ../../data/raw/recordings/104512.mp3 already downloaded
# ../../data/raw/recordings/144812.mp3 already downloaded
# ../../data/raw/recordings/144812.mp3 already downloaded
# ../../data/raw/recordings/104526.mp3 already downloaded
# ../../data/raw/recordings/104526.mp3 already downloaded
# ../../data/raw/recordings/104526.mp3 already downloaded
# ../../data/raw/recordings/40330.mp3 already downloaded
# ../../data/raw/recordings/40330.mp3 already downloaded
# ../../data/raw/recordings/40331.mp3 already downloaded
# ../../data/raw/recordings/40331.mp3 already downloaded
# ../../data/raw/recordings/40331.mp3 already downloaded
# ../../data/raw/recordings/40333.mp3 already downloaded
# ../../data/raw/recordings/40342.mp3 already downloaded
# ../../data/raw/recordings/40344.mp3 already downloaded
# ../../data/raw/recordings/40344.mp3 already downloaded
# ../../data/raw/recordings/40344.mp3 already downloaded
# ../../data/raw/recordings/40348.mp3 already downloaded
# ../../data/raw/recordings/40348.mp3 already downloaded
# ../../data/raw/recordings/40348.mp3 already downloaded
# ../../data/raw/recordings/40345.mp3 already downloaded
# ../../data/raw/recordings/40345.mp3 already downloaded
# ../../data/raw/recordings/40345.mp3 already downloaded
# ../../data/raw/recordings/40346.mp3 already downloaded
# ../../data/raw/recordings/40346.mp3 already downloaded
# ../../data/raw/recordings/40346.mp3 already downloaded
# ../../data/raw/recordings/40360.mp3 already downloaded
# ../../data/raw/recordings/40360.mp3 already downloaded
# ../../data/raw/recordings/40360.mp3 already downloaded
# ../../data/raw/recordings/40358.mp3 already downloaded
# ../../data/raw/recordings/40358.mp3 already downloaded
# ../../data/raw/recordings/40361.mp3 already downloaded
# ../../data/raw/recordings/40361.mp3 already downloaded
# ../../data/raw/recordings/40361.mp3 already downloaded
# ../../data/raw/recordings/40368.mp3 already downloaded
# ../../data/raw/recordings/40366.mp3 already downloaded
# ../../data/raw/recordings/40366.mp3 already downloaded
# ../../data/raw/recordings/40363.mp3 already downloaded
# ../../data/raw/recordings/40363.mp3 already downloaded
# ../../data/raw/recordings/40363.mp3 already downloaded
# ../../data/raw/recordings/40364.mp3 already downloaded
# ../../data/raw/recordings/40364.mp3 already downloaded
# ../../data/raw/recordings/40364.mp3 already downloaded
# ../../data/raw/recordings/40249.mp3 already downloaded
# ../../data/raw/recordings/40249.mp3 already downloaded
# ../../data/raw/recordings/40249.mp3 already downloaded
# ../../data/raw/recordings/104671.mp3 already downloaded
# ../../data/raw/recordings/104696.mp3 already downloaded
# ../../data/raw/recordings/104696.mp3 already downloaded
# ../../data/raw/recordings/104216.mp3 already downloaded
# ../../data/raw/recordings/104274.mp3 already downloaded
# ../../data/raw/recordings/104274.mp3 already downloaded
# ../../data/raw/recordings/104311.mp3 already downloaded
# ../../data/raw/recordings/104311.mp3 already downloaded
# ../../data/raw/recordings/104311.mp3 already downloaded
# ../../data/raw/recordings/104316.mp3 already downloaded
# ../../data/raw/recordings/104316.mp3 already downloaded
# ../../data/raw/recordings/104316.mp3 already downloaded
# ../../data/raw/recordings/104315.mp3 already downloaded
# ../../data/raw/recordings/104315.mp3 already downloaded
# ../../data/raw/recordings/104314.mp3 already downloaded
# ../../data/raw/recordings/104317.mp3 already downloaded
# ../../data/raw/recordings/104317.mp3 already downloaded
# ../../data/raw/recordings/104317.mp3 already downloaded
# ../../data/raw/recordings/104320.mp3 already downloaded
# ../../data/raw/recordings/104320.mp3 already downloaded
# ../../data/raw/recordings/104320.mp3 already downloaded
# ../../data/raw/recordings/104318.mp3 already downloaded
# ../../data/raw/recordings/104318.mp3 already downloaded
# ../../data/raw/recordings/104318.mp3 already downloaded
# ../../data/raw/recordings/104342.mp3 already downloaded
# ../../data/raw/recordings/104342.mp3 already downloaded
# ../../data/raw/recordings/104342.mp3 already downloaded
# ../../data/raw/recordings/104384.mp3 already downloaded
# ../../data/raw/recordings/104384.mp3 already downloaded
# ../../data/raw/recordings/104384.mp3 already downloaded
# ../../data/raw/recordings/171058.mp3 already downloaded
# ../../data/raw/recordings/170398.mp3 already downloaded
# ../../data/raw/recordings/170398.mp3 already downloaded
# ../../data/raw/recordings/170427.mp3 already downloaded
# ../../data/raw/recordings/170427.mp3 already downloaded
# ../../data/raw/recordings/170427.mp3 already downloaded
# ../../data/raw/recordings/170342.mp3 already downloaded
# ../../data/raw/recordings/170504.mp3 already downloaded
# ../../data/raw/recordings/169187.mp3 already downloaded
# ../../data/raw/recordings/169920.mp3 already downloaded
# ../../data/raw/recordings/168894.mp3 already downloaded
# ../../data/raw/recordings/168894.mp3 already downloaded
# ../../data/raw/recordings/168894.mp3 already downloaded
# ../../data/raw/recordings/168946.mp3 already downloaded
# ../../data/raw/recordings/168946.mp3 already downloaded
# ../../data/raw/recordings/168946.mp3 already downloaded
# ../../data/raw/recordings/169982.mp3 already downloaded
# ../../data/raw/recordings/173150.mp3 already downloaded
# ../../data/raw/recordings/173150.mp3 already downloaded
# ../../data/raw/recordings/173150.mp3 already downloaded
# ../../data/raw/recordings/100325.mp3 already downloaded
# ../../data/raw/recordings/100325.mp3 already downloaded
# ../../data/raw/recordings/100325.mp3 already downloaded
# ../../data/raw/recordings/100328.mp3 already downloaded
# ../../data/raw/recordings/100328.mp3 already downloaded
# ../../data/raw/recordings/100327.mp3 already downloaded
# ../../data/raw/recordings/100329.mp3 already downloaded
# ../../data/raw/recordings/100329.mp3 already downloaded
# ../../data/raw/recordings/100330.mp3 already downloaded
# ../../data/raw/recordings/100330.mp3 already downloaded
# ../../data/raw/recordings/100330.mp3 already downloaded
# ../../data/raw/recordings/100399.mp3 already downloaded
# ../../data/raw/recordings/79961.mp3 already downloaded
# ../../data/raw/recordings/186840.mp3 already downloaded
# ../../data/raw/recordings/186839.mp3 already downloaded
# ../../data/raw/recordings/186843.mp3 already downloaded
# ../../data/raw/recordings/168194.mp3 already downloaded
# ../../data/raw/recordings/186153.mp3 already downloaded
# ../../data/raw/recordings/177396.mp3 already downloaded
# ../../data/raw/recordings/186863.mp3 already downloaded
# ../../data/raw/recordings/186862.mp3 already downloaded
# ../../data/raw/recordings/186922.mp3 already downloaded
# ../../data/raw/recordings/186920.mp3 already downloaded
# ../../data/raw/recordings/186928.mp3 already downloaded
# ../../data/raw/recordings/186921.mp3 already downloaded
# ../../data/raw/recordings/186923.mp3 already downloaded
# ../../data/raw/recordings/186162.mp3 already downloaded
# ../../data/raw/recordings/186167.mp3 already downloaded
# ../../data/raw/recordings/140875.mp3 already downloaded
# ../../data/raw/recordings/140928.mp3 already downloaded
# ../../data/raw/recordings/140904.mp3 already downloaded
# ../../data/raw/recordings/163987.mp3 already downloaded
# ../../data/raw/recordings/141113.mp3 already downloaded
# ../../data/raw/recordings/141104.mp3 already downloaded
# ../../data/raw/recordings/163983.mp3 already downloaded
# ../../data/raw/recordings/97499.mp3 already downloaded
# ../../data/raw/recordings/97528.mp3 already downloaded
# ../../data/raw/recordings/165484.mp3 already downloaded
# ../../data/raw/recordings/97768.mp3 already downloaded
# ../../data/raw/recordings/97773.mp3 already downloaded
# ../../data/raw/recordings/97773.mp3 already downloaded
# ../../data/raw/recordings/97774.mp3 already downloaded
# ../../data/raw/recordings/97806.mp3 already downloaded
# ../../data/raw/recordings/97807.mp3 already downloaded
# ../../data/raw/recordings/97916.mp3 already downloaded
# ../../data/raw/recordings/97917.mp3 already downloaded
# ../../data/raw/recordings/97934.mp3 already downloaded
# ../../data/raw/recordings/97976.mp3 already downloaded
# ../../data/raw/recordings/97977.mp3 already downloaded
# ../../data/raw/recordings/97978.mp3 already downloaded
# ../../data/raw/recordings/97979.mp3 already downloaded
# ../../data/raw/recordings/97985.mp3 already downloaded
# ../../data/raw/recordings/97986.mp3 already downloaded
# ../../data/raw/recordings/97989.mp3 already downloaded
# ../../data/raw/recordings/97995.mp3 already downloaded
# ../../data/raw/recordings/97997.mp3 already downloaded
# ../../data/raw/recordings/98002.mp3 already downloaded
# ../../data/raw/recordings/98006.mp3 already downloaded
# ../../data/raw/recordings/98132.mp3 already downloaded
# ../../data/raw/recordings/98133.mp3 already downloaded
# ../../data/raw/recordings/343222.mp3 already downloaded
# ../../data/raw/recordings/282314.mp3 already downloaded
# ../../data/raw/recordings/343221.mp3 already downloaded
# ../../data/raw/recordings/277670.mp3 already downloaded
# ../../data/raw/recordings/277722.mp3 already downloaded
# ../../data/raw/recordings/282961.mp3 already downloaded
# ../../data/raw/recordings/282958.mp3 already downloaded
# ../../data/raw/recordings/277779.mp3 already downloaded
# ../../data/raw/recordings/277784.mp3 already downloaded
# ../../data/raw/recordings/277785.mp3 already downloaded
# ../../data/raw/recordings/277785.mp3 already downloaded
# ../../data/raw/recordings/282499.mp3 already downloaded
# ../../data/raw/recordings/283549.mp3 already downloaded
# ../../data/raw/recordings/283551.mp3 already downloaded
# ../../data/raw/recordings/283550.mp3 already downloaded
# ../../data/raw/recordings/283557.mp3 already downloaded
# ../../data/raw/recordings/279403.mp3 already downloaded
# ../../data/raw/recordings/280076.mp3 already downloaded
# ../../data/raw/recordings/280096.mp3 already downloaded
# ../../data/raw/recordings/280093.mp3 already downloaded
# ../../data/raw/recordings/282687.mp3 already downloaded
# ../../data/raw/recordings/280349.mp3 already downloaded
# ../../data/raw/recordings/282767.mp3 already downloaded
# ../../data/raw/recordings/282763.mp3 already downloaded
# ../../data/raw/recordings/282759.mp3 already downloaded
# ../../data/raw/recordings/280433.mp3 already downloaded

# %% [markdown]
# # Downloader

# %%
for rec in (osfls.index):
    clip_url=osfls.clip_url[rec]
    ext = osfls.file_type[rec]
    path = 'data/recordings'
    fname = f'{path}/{osfls.recording_id[rec]}.{ext}'
    if exists(fname):
        pass
    else:
        r = requests.get(clip_url)
        with open(fname, 'wb') as f:
            f.write(r.content)
