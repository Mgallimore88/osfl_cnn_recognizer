# %% [markdown]
# # Use HawkEars predictions to find clear, focal samples of OSFL calls.
#
# This is done in order to try to preserve the relationship between sound power level in the input audio, and the output score of the model, such that louder and hence closer bird calls produces a higher score and further away calls produce a lower score.
#
# This is a requirement of downstream statistical applications of the model, such as estimating bird density from the output scores.
#
# The initial dataset contains only a random sample of the first call heard by a human listener within a certain time interval. This provides a range of signal to noise ratios, which is representative of what is expected in the field, however, the first call heard is not always the clearest call. Therefore the HawkEars model was run to find the clearest calls, and these can be mixed into the traininig dataset.
#
# ## Some considerations
#
# - The dataset was split 80/20 into training and testing data. The 20% test data is left untouched, and the remaining 80% has been further split into a validation and training set.
#
# - The dataset is the set of recordings which at some point had an olive sided flycatcher call detected by a human listener. This means that sounds from other habitats are not present in the dataset. The effects of this should be tested by adding sounds from ohter habitats to the training set.
#
# - It is the training set which needs augmenting with the clearest calls.
#
# - The clearest calls are found by taking the top 1% of the scores from the HawkEars model. This is a somewhat arbitrary choice, but it is a good starting point.

# %% [markdown]
# ## The process
# To get the hawkears predictions, the following steps were taken:
# 1. Output the URLS of all the recordings in the training set to a file
# 2. open up a google colab instance and download all the recordings in the training set
# 3. run the HawkEars model on the recordings and save the predictions in a folder.
# 4. Finally this folder was dragged into the data/processed folder of this repo.
#
# - The hawkears model was in its 'out of the box' state on 7th Feb 2024. Threshold is 0.7
# - This took 74m to run on a paid instance v100 GPU and cost 5.36 compute units per hour.

# %%
# imports
import glob
from pathlib import Path
import pandas as pd
from pandas.errors import EmptyDataError

# for utils
from pathlib import Path
import sys
BASE_PATH = Path.cwd().parent.parent
sys.path.append(str(BASE_PATH))
from src.utils import display_all, keep_cols
import src.utils as utils
import sklearn
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score, average_precision_score, roc_auc_score, precision_recall_curve

import matplotlib.pyplot as plt
import torch

# %%
data_path = Path.cwd().parent.parent / 'data'

# %% [markdown]
# # Look at the dataset which will be used to generate the focal recordings
# - it consists of the 80% of the full dataset, with a further 20% removed for use as a validation set during training.

# %%
train_split = pd.read_pickle(data_path / "processed" / "train_set" / 'train_split.pkl')
train_split.head()
# Out:
#                                                   recording_url task_method  \
# recording_id
# 4396          https://wildtrax-aru.s3.us-west-2.amazonaws.co...        1SPM
# 4427          https://wildtrax-aru.s3.us-west-2.amazonaws.co...        1SPM
# 4429          https://wildtrax-aru.s3.us-west-2.amazonaws.co...        1SPM
# 4446          https://wildtrax-aru.s3.us-west-2.amazonaws.co...        1SPM
# 4452          https://wildtrax-aru.s3.us-west-2.amazonaws.co...        1SPM
#
#                                           project         detection_time  \
# recording_id
# 4396          Boreal Wetland Community Monitoring          [27.28, 95.9]
# 4427          Boreal Wetland Community Monitoring       [106.56, 122.66]
# 4429          Boreal Wetland Community Monitoring  [31.11, 74.7, 139.78]
# 4446          Boreal Wetland Community Monitoring  [13.63, 74.88, 126.6]
# 4452          Boreal Wetland Community Monitoring         [11.31, 169.2]
#
#                     tag_duration   latitude   longitude file_type  \
# recording_id
# 4396                [0.83, 1.18]  57.292989 -111.412116       mp3
# 4427                 [1.0, 0.84]  57.302163 -111.376885       mp3
# 4429          [1.38, 2.19, 1.29]  57.302163 -111.376885       mp3
# 4446           [1.05, 0.89, 0.8]  57.482905 -111.378761       mp3
# 4452                [0.96, 1.18]  57.482905 -111.378761       mp3
#
#                                                       media_url  \
# recording_id
# 4396          https://portal.wildtrax.ca/home/aru-tasks/reco...
# 4427          https://portal.wildtrax.ca/home/aru-tasks/reco...
# 4429          https://portal.wildtrax.ca/home/aru-tasks/reco...
# 4446          https://portal.wildtrax.ca/home/aru-tasks/reco...
# 4452          https://portal.wildtrax.ca/home/aru-tasks/reco...
#
#               individual_order  location_id  is_valid
# recording_id
# 4396                       1.0          355     False
# 4427                       1.0          359     False
# 4429                       1.0          359     False
# 4446                       1.0          362     False
# 4452                       1.0          362     False

# %%
len(train_split.index.values)
# Out:
# 2371

# %% [markdown]
# Make sure that the training set split corresponds to the downloaded recordings I have on disk.

# %%
recordings_on_disk = glob.glob(str(data_path / "raw" / "recordings" / "OSFL") + "/*.*")
recording_ids = [file.split("/")[-1].split(".")[0].split("-")[1] for file in recordings_on_disk]
len(recording_ids), len(train_split) / len(recording_ids), len(train_split)
# Out:
# (2897, 0.8184328615809459, 2371)

# %% [markdown]
# There are 2897 recordings downloaded, but only 2371 of these are in the training set after the validation split.
#
# Filter the recordings on disk to only include the ones in the training set.

# %%
def get_recording_id(file):
    return int(file.split("/")[-1].split(".")[0].split("-")[1])

train_recs = [file for file in recordings_on_disk if get_recording_id(file) in train_split.index.values]

len(train_recs)
# Out:
# 2308

# %% [markdown]
# After filtering the reocrdings on disk to include only the ones in the training set, there are only 2308 recordings instead of the expected 2371. It is not clear why this is the case.

# %% [markdown]
# # We want to augment the training set with high quality recordings.
# HawkEars was run on the training set and any scores over 0.7 were saved.
#
# Filter out the other birds and OSFL calls from these recordings and count how many detections there are.

# %%
hawkears_output_files = glob.glob(str(data_path/'processed'/'hawkears_predictions/*.txt'))
len(hawkears_output_files)
# Out:
# 2371

# %%
def get_recording_id(hawkears_out):
    return int(hawkears_out.split("/")[-1].split(".")[0].split("_")[0])

# %%
dfs = []
for file in hawkears_output_files:
    print(f"processing {file}")
    recording_id = get_recording_id(file)
    try:
        df = pd.read_csv(file, sep="\t", header=None)
        df.columns = ["start", "end", "label;score"]
        df["recording_id"] = recording_id
    except EmptyDataError:
        print("(file was empty)")
        continue
    dfs.append(df)
# Out:
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/292337_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/293662_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/555135_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/556684_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/815670_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/556082_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/294585_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/291905_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/43757_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/296135_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/555132_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/826263_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/316137_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/552486_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/553186_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/552872_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/48536_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/294384_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/554316_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/186921_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/218246_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/556158_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/554234_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/297299_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/292563_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/293063_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/292997_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/294582_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/168751_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/294259_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/291902_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/291957_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/297079_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/296927_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/305167_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/555581_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/294737_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/248853_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/816373_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/390987_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/291743_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/295546_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/553399_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/295431_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/295464_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/553333_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/552666_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/305010_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/99092_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/816204_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/294615_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/296920_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/255457_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/555586_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/815864_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/279403_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/622389_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/553993_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/554708_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/622452_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/557013_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/557046_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/552716_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/156401_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/293876_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/295868_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/553334_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/294136_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/295436_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/555805_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/292659_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/292207_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/4787_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/566242_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/555005_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/297226_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/292576_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions
HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/296011_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/552874_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/552480_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/816793_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/294382_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/556685_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/554461_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/554895_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/826265_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/555134_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/286234_HawkEars.txt
# ...
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/294110_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/553347_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/552647_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/768522_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/144812_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/556399_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/816270_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/541580_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/576936_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/296824_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/97806_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/298091_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/555889_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/291854_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/48542_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/553158_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/295181_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/293160_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/282767_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/296665_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/538547_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/613113_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/297247_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/104671_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/103815_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/552971_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/321023_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/294278_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/552924_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/320982_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/613712_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/141104_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/294479_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/816068_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/293167_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/292467_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/292510_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/297240_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/555747_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/552923_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/556787_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/315728_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/300380_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/566224_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/292234_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/553489_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/297190_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/296831_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/538718_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/295450_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/294105_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/817014_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/291600_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/40342_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/50045_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/291777_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/556981_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/293539_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/292039_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/622461_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/292093_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/553501_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/255431_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/71468_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/297197_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/282961_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/293338_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/304982_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/552655_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/558044_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/295457_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/482321_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/50042_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/292149_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/40345_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/296319_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/610256_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/768530_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/556986_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/552777_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/553277_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/556979_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/292094_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/294751_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/357693_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/291590_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/291964_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/552963_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/70985_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/552568_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/554982_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/566231_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/163473_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/554589_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/292505_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/293005_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/816082_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/538500_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/292886_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/292427_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/413785_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/294348_HawkEars.txt
# (file was empty)
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/293656_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/292303_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/283551_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/555154_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/555101_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/294292_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/295792_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/291568_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/552590_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/552964_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/293773_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/566236_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/826375_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/555071_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/541657_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/186862_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/538470_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/293057_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/292502_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/294860_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/217366_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/292475_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/292420_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/293120_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/297325_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/556648_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/413782_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/555153_HawkEars.txt
# processing /Users/mikeg/code/machine_learning/osfl_cnn_recognizer/data/processed/hawkears_predictions/293651_HawkEars.txt

# %% [markdown]
# ### Add the full file path to the recordings df since this is used by opensoundscape for finding files

# %%
recordings_df = pd.DataFrame(recordings_on_disk, columns=["full_path"])
recordings_df['file_id'] = recordings_df['full_path'].apply(lambda x: int(x.split("/")[-1].split(".")[0].split("-")[1]))
recordings_df['file_extension'] = recordings_df['full_path'].apply(lambda x: x.split("/")[-1].split(".")[1])

# %% [markdown]
# Drop the recordings which are not in the training set, since this is a potential source of data leakage from validation into training set.

# %%
# drop the recordings_df rows which are not in the train_split 
recordings_df = recordings_df[recordings_df['file_id'].isin(train_split.index.values)]
# make a dictionary from file id to file extension
file_id_to_ext_dict = recordings_df.set_index('file_id')['file_extension'].to_dict()

# %% [markdown]
# # Make a new dataframe from the hawkears output
# - contains the relative path to each recording file
# - contains the start, end and species tag for each detection
# - therefore we can easily convert these into an opensoundscape AudioFileDataset.

# %%
result_df = pd.concat(dfs, ignore_index=True)
result_df[['label', 'score']] = result_df['label;score'].str.split(';', expand=True)
del(result_df['label;score'])

result_df['file_extension'] = result_df['recording_id'].map(lambda x: file_id_to_ext_dict.get(x, 'Missing'))

result_df.drop(result_df[result_df['file_extension'] == 'Missing'].index, inplace=True)

# %%
# concat and parse the hawkears output files
result_df = pd.concat(dfs, ignore_index=True)
result_df[['label', 'score']] = result_df['label;score'].str.split(';', expand=True)
del(result_df['label;score'])

# explicitly drop entries which were not in both the train split and the downloaded recordings.
result_df.drop(result_df[~result_df['recording_id'].isin(file_id_to_ext_dict.keys())].index, inplace=True)
result_df['file_extension'] = result_df['recording_id'].map(lambda x: file_id_to_ext_dict[x])
len(result_df)
# Out:
# 69832

# %%
start_of_path = "../../data/raw/recordings/OSFL/recording-"
result_df['full_path'] = start_of_path + result_df['recording_id'].astype(str) + "." + result_df['file_extension']
# drop all the rows where the label is not "OSFL"
result_df.drop(result_df[result_df['label'] != 'OSFL'].index, inplace=True)
# drop all the rows where the score is less than 0.99
top_osfls = result_df.drop(result_df[result_df['score'].astype(float) < 0.97].index)
top_osfls.head()
# Out:
#      start   end  recording_id label score file_extension  \
# 41     0.0  60.0        555135  OSFL  1.00           flac
# 89    63.0  67.5        815670  OSFL  0.98           flac
# 327    0.0  12.0        555132  OSFL  0.99           flac
# 328   13.5  27.0        555132  OSFL  0.99           flac
# 329   45.0  58.5        555132  OSFL  0.99           flac
#
#                                              full_path
# 41   ../../data/raw/recordings/OSFL/recording-55513...
# 89   ../../data/raw/recordings/OSFL/recording-81567...
# 327  ../../data/raw/recordings/OSFL/recording-55513...
# 328  ../../data/raw/recordings/OSFL/recording-55513...
# 329  ../../data/raw/recordings/OSFL/recording-55513...

# %%
len(top_osfls)
# Out:
# 1426

# %%
top_osfls.set_index(['full_path', 'start', 'end'])
# Out:
#                                                                 recording_id  \
# full_path                                          start end
# ../../data/raw/recordings/OSFL/recording-555135... 0.0   60.0         555135
# ../../data/raw/recordings/OSFL/recording-815670... 63.0  67.5         815670
# ../../data/raw/recordings/OSFL/recording-555132... 0.0   12.0         555132
#                                                    13.5  27.0         555132
#                                                    45.0  58.5         555132
# ...                                                                      ...
# ../../data/raw/recordings/OSFL/recording-293120... 78.0  99.0         293120
#                                                    100.5 108.0        293120
#                                                    111.0 135.0        293120
#                                                    136.5 174.0        293120
# ../../data/raw/recordings/OSFL/recording-556648... 31.5  49.5         556648
#
#                                                                label score  \
# full_path                                          start end
# ../../data/raw/recordings/OSFL/recording-555135... 0.0   60.0   OSFL  1.00
# ../../data/raw/recordings/OSFL/recording-815670... 63.0  67.5   OSFL  0.98
# ../../data/raw/recordings/OSFL/recording-555132... 0.0   12.0   OSFL  0.99
#                                                    13.5  27.0   OSFL  0.99
#                                                    45.0  58.5   OSFL  0.99
# ...                                                              ...   ...
# ../../data/raw/recordings/OSFL/recording-293120... 78.0  99.0   OSFL  0.98
#                                                    100.5 108.0  OSFL  0.97
#                                                    111.0 135.0  OSFL  0.98
#                                                    136.5 174.0  OSFL  0.98
# ../../data/raw/recordings/OSFL/recording-556648... 31.5  49.5   OSFL  0.98
#
#                                                                file_extension
# full_path                                          start end
# ../../data/raw/recordings/OSFL/recording-555135... 0.0   60.0            flac
# ../../data/raw/recordings/OSFL/recording-815670... 63.0  67.5            flac
# ../../data/raw/recordings/OSFL/recording-555132... 0.0   12.0            flac
#                                                    13.5  27.0            flac
#                                                    45.0  58.5            flac
# ...                                                                       ...
# ../../data/raw/recordings/OSFL/recording-293120... 78.0  99.0             mp3
#                                                    100.5 108.0            mp3
#                                                    111.0 135.0            mp3
#                                                    136.5 174.0            mp3
# ../../data/raw/recordings/OSFL/recording-556648... 31.5  49.5            flac
#
# [1426 rows x 4 columns]
